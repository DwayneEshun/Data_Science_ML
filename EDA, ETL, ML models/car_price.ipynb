# %%
import pandas as pd
import numpy as np

# %%
cars = pd.read_csv('car_price_datatset.csv.xls')
# Out:
#   Make       Model  Year             Engine Fuel Type  Engine HP  \
# 0  BMW  1 Series M  2011  premium unleaded (required)      335.0
# 1  BMW    1 Series  2011  premium unleaded (required)      300.0
# 2  BMW    1 Series  2011  premium unleaded (required)      300.0
# 3  BMW    1 Series  2011  premium unleaded (required)      230.0
# 4  BMW    1 Series  2011  premium unleaded (required)      230.0
#
#    Engine Cylinders Transmission Type     Driven_Wheels  Number of Doors  \
# 0               6.0            MANUAL  rear wheel drive              2.0
# 1               6.0            MANUAL  rear wheel drive              2.0
# 2               6.0            MANUAL  rear wheel drive              2.0
# 3               6.0            MANUAL  rear wheel drive              2.0
# 4               6.0            MANUAL  rear wheel drive              2.0
#
#                          Market Category Vehicle Size Vehicle Style  \
# ...

# %%
cars.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         6
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
cars.dtypes
cars.info()
cars.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11908 non-null  float64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
cars['Vehicle Size'].unique()
# Out:
# array(['Compact', 'Midsize', 'Large'], dtype=object)

# %%
cars['Number of Doors'] = cars['Number of Doors'].fillna(4)

# %%
cars[cars['Number of Doors'].isnull()].head(60)
cars[cars['Vehicle Size'] == 'Large'].groupby('Make')['Number of Doors'].agg('max')
# Out:
# Make
# Aston Martin     4.0
# Audi             4.0
# BMW              4.0
# Bentley          4.0
# Buick            4.0
# Cadillac         4.0
# Chevrolet        4.0
# Chrysler         4.0
# Dodge            4.0
# Ferrari          2.0
# Ford             4.0
# GMC              4.0
# Genesis          4.0
# Honda            4.0
# Hyundai          4.0
# Infiniti         4.0
# Kia              4.0
# Land Rover       4.0
# Lexus            4.0
# Lincoln          4.0
# Maserati         4.0
# Maybach          4.0
# Mazda            4.0
# Mercedes-Benz    4.0
# Nissan           4.0
# Oldsmobile       4.0
# Plymouth         4.0
# Pontiac          4.0
# Porsche          4.0
# Rolls-Royce      4.0
# Saab             4.0
# Tesla            4.0
# Toyota           4.0
# Volkswagen       4.0
# Volvo            4.0
# Name: Number of Doors, dtype: float64

# %%
cars['Number of Doors'] = cars['Number of Doors'].astype('int64')

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11914 non-null  int64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
cars.columns = cars.columns.str.replace(' ', '_')

# %%
cars.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine Fuel Type        3
# Engine HP              69
# Engine Cylinders       30
# Transmission Type       0
# Driven_Wheels           0
# Number of Doors         0
# Market Category      3742
# Vehicle Size            0
# Vehicle Style           0
# highway MPG             0
# city mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
cars['Engine Cylinders'].unique()
# Out:
# array([ 6.,  4.,  5.,  8., 12.,  0., nan, 10.,  3., 16.])

# %%
cars[cars['Transmission Type'] == 'DIRECT_DRIVE'].fillna(0)
# Out:
#                Make                   Model  Year Engine Fuel Type  Engine HP  \
# 539            FIAT                    500e  2015         electric        0.0
# 540            FIAT                    500e  2016         electric        0.0
# 541            FIAT                    500e  2017         electric        0.0
# 1680  Mercedes-Benz  B-Class Electric Drive  2015         electric      177.0
# 1681  Mercedes-Benz  B-Class Electric Drive  2016         electric      177.0
# ...             ...                     ...   ...              ...        ...
# 9868      Chevrolet                Spark EV  2014         electric      140.0
# 9869      Chevrolet                Spark EV  2015         electric      140.0
# 9870      Chevrolet                Spark EV  2015         electric      140.0
# 9871      Chevrolet                Spark EV  2016         electric      140.0
# 9872      Chevrolet                Spark EV  2016         electric      140.0
#
# ...

# %%
cars[cars['Transmission Type'] == 'DIRECT_DRIVE']
# Out:
#                Make                   Model  Year Engine Fuel Type  Engine HP  \
# 539            FIAT                    500e  2015         electric        NaN
# 540            FIAT                    500e  2016         electric        NaN
# 541            FIAT                    500e  2017         electric        NaN
# 1680  Mercedes-Benz  B-Class Electric Drive  2015         electric      177.0
# 1681  Mercedes-Benz  B-Class Electric Drive  2016         electric      177.0
# ...             ...                     ...   ...              ...        ...
# 9868      Chevrolet                Spark EV  2014         electric      140.0
# 9869      Chevrolet                Spark EV  2015         electric      140.0
# 9870      Chevrolet                Spark EV  2015         electric      140.0
# 9871      Chevrolet                Spark EV  2016         electric      140.0
# 9872      Chevrolet                Spark EV  2016         electric      140.0
#
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine Fuel Type   11911 non-null  object
#  4   Engine HP          11845 non-null  float64
#  5   Engine Cylinders   11884 non-null  float64
#  6   Transmission Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number of Doors    11914 non-null  int64
#  9   Market Category    8172 non-null   object
#  10  Vehicle Size       11914 non-null  object
#  11  Vehicle Style      11914 non-null  object
#  12  highway MPG        11914 non-null  int64
#  13  city mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
cars[(cars['Engine Cylinders'].isnull()) & (cars['Transmission Type'] == 'DIRECT_DRIVE')]
# Out:
#             Make    Model  Year Engine Fuel Type  Engine HP  Engine Cylinders  \
# 1983   Chevrolet  Bolt EV  2017         electric      200.0               NaN
# 1984   Chevrolet  Bolt EV  2017         electric      200.0               NaN
# 3716  Volkswagen   e-Golf  2015         electric      115.0               NaN
# 3717  Volkswagen   e-Golf  2015         electric      115.0               NaN
# 3718  Volkswagen   e-Golf  2016         electric      115.0               NaN
# 3719  Volkswagen   e-Golf  2016         electric      115.0               NaN
# 5778  Mitsubishi   i-MiEV  2014         electric        NaN               NaN
# 5779  Mitsubishi   i-MiEV  2016         electric       66.0               NaN
# 5780  Mitsubishi   i-MiEV  2017         electric       66.0               NaN
# 8373      Toyota  RAV4 EV  2012         electric      154.0               NaN
#
#      Transmission Type      Driven_Wheels  Number of Doors Market Category  \
# ...

# %%
cars[cars['Transmission Type'] == 'DIRECT_DRIVE'].head(60)
# Out:
#                Make                   Model  Year  Engine Fuel Type  \
# 539            FIAT                    500e  2015          electric
# 540            FIAT                    500e  2016          electric
# 541            FIAT                    500e  2017          electric
# 1680  Mercedes-Benz  B-Class Electric Drive  2015          electric
# 1681  Mercedes-Benz  B-Class Electric Drive  2016          electric
# 1682  Mercedes-Benz  B-Class Electric Drive  2017          electric
# 1983      Chevrolet                 Bolt EV  2017          electric
# 1984      Chevrolet                 Bolt EV  2017          electric
# 3716     Volkswagen                  e-Golf  2015          electric
# 3717     Volkswagen                  e-Golf  2015          electric
# 3718     Volkswagen                  e-Golf  2016          electric
# 3719     Volkswagen                  e-Golf  2016          electric
# 4705          Honda                  Fit EV  2013          electric
# ...
