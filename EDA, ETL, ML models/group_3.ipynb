# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
import plotly.express as px

# %%
car_price = pd.read_csv('car_price_datatset.csv.xls')

# %%
car_price.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine Fuel Type', 'Engine HP',
#        'Engine Cylinders', 'Transmission Type', 'Driven_Wheels',
#        'Number of Doors', 'Market Category', 'Vehicle Size', 'Vehicle Style',
#        'highway MPG', 'city mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
car_price1 = car_price.copy()

# %% [markdown]
# # Data Cleaning

# %%
car_price1.columns  = car_price1.columns.str.replace(' ', '_')

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11911 non-null  object
#  4   Engine_HP          11845 non-null  float64
#  5   Engine_Cylinders   11884 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11908 non-null  float64
#  9   Market_Category    8172 non-null   object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  int64
#  13  city_mpg           11914 non-null  int64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  int64
# ...

# %%
#Engine Cylinders : Float - int✅
#Number of doors : Float - int✅
#Highway/city MPG : int - Float✅
#MSRP : int - Float✅

car_price1.highway_MPG = car_price1.highway_MPG.astype('float64')
car_price1.city_mpg = car_price1.city_mpg.astype('float64')
car_price1.MSRP = car_price1.MSRP.astype('float64')

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11911 non-null  object
#  4   Engine_HP          11845 non-null  float64
#  5   Engine_Cylinders   11884 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11908 non-null  float64
#  9   Market_Category    8172 non-null   object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11911 non-null  object
#  4   Engine_HP          11845 non-null  float64
#  5   Engine_Cylinders   11884 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11908 non-null  float64
#  9   Market_Category    8172 non-null   object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              69
# Engine_Cylinders       30
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         6
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              69
# Engine_Cylinders       30
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         6
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.head(60)
# Out:
#              Make       Model  Year  ... city_mpg  Popularity     MSRP
# 0             BMW  1 Series M  2011  ...     19.0        3916  46135.0
# 1             BMW    1 Series  2011  ...     19.0        3916  40650.0
# 2             BMW    1 Series  2011  ...     20.0        3916  36350.0
# 3             BMW    1 Series  2011  ...     18.0        3916  29450.0
# 4             BMW    1 Series  2011  ...     18.0        3916  34500.0
# 5             BMW    1 Series  2012  ...     18.0        3916  31200.0
# 6             BMW    1 Series  2012  ...     17.0        3916  44100.0
# 7             BMW    1 Series  2012  ...     20.0        3916  39300.0
# 8             BMW    1 Series  2012  ...     18.0        3916  36900.0
# 9             BMW    1 Series  2013  ...     18.0        3916  37200.0
# 10            BMW    1 Series  2013  ...     20.0        3916  39600.0
# 11            BMW    1 Series  2013  ...     19.0        3916  31500.0
# ...

# %%
car_price1.Number_of_Doors.unique()
# Out:
# array([ 2.,  4.,  3., nan])

# %%
car_price1.Number_of_Doors.fillna(4, inplace = True)
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1234765547.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_price1.Number_of_Doors.fillna(4, inplace = True)

# %%
car_price1.Number_of_Doors.unique()
# Out:
# array([2., 4., 3.])

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              69
# Engine_Cylinders       30
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.Number_of_Doors = car_price1.Number_of_Doors.astype('int64', copy = False)

# %%
car_price1.Engine_Cylinders.isnull().sum()
# Out:
# np.int64(30)

# %%
car_price1[car_price1.Engine_Fuel_Type == 'electric']
# Out:
#                Make                   Model  ...  Popularity     MSRP
# 539            FIAT                    500e  ...         819  31800.0
# 540            FIAT                    500e  ...         819  31800.0
# 541            FIAT                    500e  ...         819  31800.0
# 1680  Mercedes-Benz  B-Class Electric Drive  ...         617  41450.0
# 1681  Mercedes-Benz  B-Class Electric Drive  ...         617  41450.0
# ...             ...                     ...  ...         ...      ...
# 9868      Chevrolet                Spark EV  ...        1385  27010.0
# 9869      Chevrolet                Spark EV  ...        1385  25170.0
# 9870      Chevrolet                Spark EV  ...        1385  25560.0
# 9871      Chevrolet                Spark EV  ...        1385  25510.0
# 9872      Chevrolet                Spark EV  ...        1385  25120.0
#
# [66 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')]
# Out:
#             Make    Model  Year  ... city_mpg  Popularity     MSRP
# 1983   Chevrolet  Bolt EV  2017  ...    128.0        1385  40905.0
# 1984   Chevrolet  Bolt EV  2017  ...    128.0        1385  36620.0
# 3716  Volkswagen   e-Golf  2015  ...    126.0         873  33450.0
# 3717  Volkswagen   e-Golf  2015  ...    126.0         873  35445.0
# 3718  Volkswagen   e-Golf  2016  ...    126.0         873  28995.0
# 3719  Volkswagen   e-Golf  2016  ...    126.0         873  35595.0
# 5778  Mitsubishi   i-MiEV  2014  ...    126.0         436  22995.0
# 5779  Mitsubishi   i-MiEV  2016  ...    126.0         436  22995.0
# 5780  Mitsubishi   i-MiEV  2017  ...    121.0         436  22995.0
# 8373      Toyota  RAV4 EV  2012  ...     78.0        2031  49800.0
#
# [10 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')] = car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')].fillna(0)

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders       20
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[car_price1.Engine_Cylinders.isnull()]
# Out:
#        Make Model  Year  ... city_mpg  Popularity     MSRP
# 8695  Mazda  RX-7  1993  ...     15.0         586   7523.0
# 8696  Mazda  RX-7  1994  ...     15.0         586   8147.0
# 8697  Mazda  RX-7  1995  ...     15.0         586   8839.0
# 8698  Mazda  RX-8  2009  ...     16.0         586  31930.0
# 8699  Mazda  RX-8  2009  ...     16.0         586  26435.0
# 8700  Mazda  RX-8  2009  ...     16.0         586  27860.0
# 8701  Mazda  RX-8  2009  ...     16.0         586  31000.0
# 8702  Mazda  RX-8  2009  ...     16.0         586  26435.0
# 8703  Mazda  RX-8  2009  ...     16.0         586  31700.0
# 8704  Mazda  RX-8  2009  ...     16.0         586  28560.0
# 8705  Mazda  RX-8  2010  ...     16.0         586  32140.0
# 8706  Mazda  RX-8  2010  ...     16.0         586  26645.0
# 8707  Mazda  RX-8  2010  ...     16.0         586  32810.0
# 8708  Mazda  RX-8  2010  ...     16.0         586  26645.0
# 8709  Mazda  RX-8  2010  ...     16.0         586  32110.0
# ...

# %%
car_price1.query('Engine_Fuel_Type == \'regular unleaded\' & Engine_HP == 255').head(60)
# Out:
#             Make              Model  Year  ... city_mpg  Popularity     MSRP
# 2671   Chevrolet    C/K 2500 Series  1998  ...     12.0        1385   3360.0
# 2672   Chevrolet    C/K 2500 Series  1998  ...     12.0        1385   3068.0
# 2673   Chevrolet    C/K 2500 Series  1998  ...     12.0        1385   3090.0
# 2674   Chevrolet    C/K 2500 Series  1998  ...     12.0        1385   2847.0
# 5789    Infiniti                I35  2004  ...     17.0         190  30600.0
# 7399    Chrysler           Pacifica  2007  ...     15.0        1013  33775.0
# 7400    Chrysler           Pacifica  2007  ...     15.0        1013  27600.0
# 7401    Chrysler           Pacifica  2007  ...     14.0        1013  27550.0
# 7402    Chrysler           Pacifica  2007  ...     14.0        1013  35825.0
# 7403    Chrysler           Pacifica  2007  ...     14.0        1013  30250.0
# 8695       Mazda               RX-7  1993  ...     15.0         586   7523.0
# ...

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'regular unleaded') & (car_price1.Engine_HP == 255)]
# Out:
#        Make Model  Year  ... city_mpg  Popularity    MSRP
# 8695  Mazda  RX-7  1993  ...     15.0         586  7523.0
# 8696  Mazda  RX-7  1994  ...     15.0         586  8147.0
# 8697  Mazda  RX-7  1995  ...     15.0         586  8839.0
#
# [3 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'regular unleaded') & (car_price1.Engine_HP == 255)] = car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'regular unleaded') & (car_price1.Engine_HP == 255)].fillna(8)

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'regular unleaded') & (car_price1.Engine_HP == 255)]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders       17
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Engine_Cylinders.isnull()) & (car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Engine_HP == 232)]
# Out:
#        Make Model  Year  ... city_mpg  Popularity     MSRP
# 8698  Mazda  RX-8  2009  ...     16.0         586  31930.0
# 8700  Mazda  RX-8  2009  ...     16.0         586  27860.0
# 8701  Mazda  RX-8  2009  ...     16.0         586  31000.0
# 8702  Mazda  RX-8  2009  ...     16.0         586  26435.0
# 8705  Mazda  RX-8  2010  ...     16.0         586  32140.0
# 8708  Mazda  RX-8  2010  ...     16.0         586  26645.0
# 8709  Mazda  RX-8  2010  ...     16.0         586  32110.0
# 8711  Mazda  RX-8  2011  ...     16.0         586  32260.0
# 8712  Mazda  RX-8  2011  ...     16.0         586  32290.0
# 8713  Mazda  RX-8  2011  ...     16.0         586  26795.0
#
# [10 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'MANUAL')]
# Out:
#       Make       Model  Year  ... city_mpg  Popularity      MSRP
# 0      BMW  1 Series M  2011  ...     19.0        3916   46135.0
# 1      BMW    1 Series  2011  ...     19.0        3916   40650.0
# 2      BMW    1 Series  2011  ...     20.0        3916   36350.0
# 3      BMW    1 Series  2011  ...     18.0        3916   29450.0
# 4      BMW    1 Series  2011  ...     18.0        3916   34500.0
# ...    ...         ...   ...  ...      ...         ...       ...
# 11897  BMW          Z4  2015  ...     22.0        3916   48950.0
# 11901  BMW          Z4  2016  ...     22.0        3916   49700.0
# 11903  BMW          Z8  2001  ...     12.0        3916  128000.0
# 11904  BMW          Z8  2002  ...     12.0        3916  130000.0
# 11905  BMW          Z8  2003  ...     12.0        3916  131500.0
#
# [481 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'MANUAL') & (car_price1.Engine_HP == 232)]
# Out:
#        Make Model  Year  ... city_mpg  Popularity     MSRP
# 8698  Mazda  RX-8  2009  ...     16.0         586  31930.0
# 8700  Mazda  RX-8  2009  ...     16.0         586  27860.0
# 8701  Mazda  RX-8  2009  ...     16.0         586  31000.0
# 8702  Mazda  RX-8  2009  ...     16.0         586  26435.0
# 8705  Mazda  RX-8  2010  ...     16.0         586  32140.0
# 8708  Mazda  RX-8  2010  ...     16.0         586  26645.0
# 8709  Mazda  RX-8  2010  ...     16.0         586  32110.0
# 8711  Mazda  RX-8  2011  ...     16.0         586  32260.0
# 8712  Mazda  RX-8  2011  ...     16.0         586  32290.0
# 8713  Mazda  RX-8  2011  ...     16.0         586  26795.0
#
# [10 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'MANUAL') & (car_price1.Engine_HP == 232)] = car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'MANUAL') & (car_price1.Engine_HP == 232)].fillna(6)

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        7
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3742
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'AUTOMATIC')].head(60)
# Out:
#          Make                  Model  Year  ... city_mpg  Popularity     MSRP
# 41        BMW               2 Series  2016  ...     23.0        3916  32850.0
# 42        BMW               2 Series  2016  ...     23.0        3916  38650.0
# 43        BMW               2 Series  2016  ...     20.0        3916  48750.0
# 44        BMW               2 Series  2016  ...     23.0        3916  34850.0
# 45        BMW               2 Series  2016  ...     22.0        3916  40650.0
# 46        BMW               2 Series  2016  ...     20.0        3916  44150.0
# 48        BMW               2 Series  2016  ...     20.0        3916  46150.0
# 49        BMW               2 Series  2016  ...     20.0        3916  50750.0
# 124       BMW  3 Series Gran Turismo  2015  ...     20.0        3916  47250.0
# 125       BMW  3 Series Gran Turismo  2015  ...     22.0        3916  41850.0
# 126       BMW  3 Series Gran Turismo  2015  ...     22.0        3916  41850.0
# ...

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'AUTOMATIC')] = car_price1[(car_price1.Engine_Fuel_Type == 'premium unleaded (required)') & (car_price1.Transmission_Type == 'AUTOMATIC')].fillna(4)

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3730
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11911 non-null  object
#  4   Engine_HP          11846 non-null  float64
#  5   Engine_Cylinders   11914 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11914 non-null  int64
#  9   Market_Category    8184 non-null   object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %%
car_price1.Engine_Cylinders.astype('int64')
# Out:
# 0        6
# 1        6
# 2        6
# 3        6
# 4        6
#         ..
# 11909    6
# 11910    6
# 11911    6
# 11912    6
# 11913    6
# Name: Engine_Cylinders, Length: 11914, dtype: int64

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3730
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.Market_Category.unique()
# Out:
# array(['Factory Tuner,Luxury,High-Performance', 'Luxury,Performance',
#        'Luxury,High-Performance', 'Luxury', 'Performance', 'Flex Fuel',
#        'Flex Fuel,Performance', nan, 'Hatchback',
#        'Hatchback,Luxury,Performance', 'Hatchback,Luxury',
#        'Luxury,High-Performance,Hybrid', 'Diesel,Luxury',
#        'Hatchback,Performance', 'Hatchback,Factory Tuner,Performance',
#        'High-Performance', 'Factory Tuner,High-Performance',
#        'Exotic,High-Performance', 'Exotic,Factory Tuner,High-Performance',
#        'Factory Tuner,Performance', 'Crossover', 'Exotic,Luxury',
#        'Exotic,Luxury,High-Performance', 'Exotic,Luxury,Performance',
#        'Factory Tuner,Luxury,Performance', 'Flex Fuel,Luxury',
#        'Crossover,Luxury', 'Hatchback,Factory Tuner,Luxury,Performance',
#        'Crossover,Hatchback', 'Hybrid', 'Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance',
# ...

# %%
car_price1[car_price1.Market_Category.isnull()]
# Out:
#          Make     Model  Year  ... city_mpg  Popularity     MSRP
# 87     Nissan     200SX  1996  ...     26.0        2009   2000.0
# 88     Nissan     200SX  1996  ...     26.0        2009   2000.0
# 91     Nissan     200SX  1997  ...     25.0        2009   2000.0
# 92     Nissan     200SX  1997  ...     25.0        2009   2000.0
# 93     Nissan     200SX  1998  ...     25.0        2009   2000.0
# ...       ...       ...   ...  ...      ...         ...      ...
# 11794  Subaru        XT  1991  ...     16.0         640   2000.0
# 11809  Toyota  Yaris iA  2017  ...     30.0        2031  15950.0
# 11810  Toyota  Yaris iA  2017  ...     32.0        2031  17050.0
# 11867     GMC     Yukon  2015  ...     15.0         549  64520.0
# 11868     GMC     Yukon  2015  ...     14.0         549  67520.0
#
# [3730 rows x 16 columns]

# %%
car_price1[(car_price1.Engine_Cylinders == 6) & (car_price1.Vehicle_Size == 'Large')].head(60)
# Out:
#               Make                  Model  Year  ... city_mpg  Popularity     MSRP
# 165  Mercedes-Benz              300-Class  1991  ...     15.0         617   2232.0
# 171  Mercedes-Benz              300-Class  1991  ...     15.0         617   2124.0
# 176  Mercedes-Benz              300-Class  1992  ...     14.0         617   2377.0
# 182  Mercedes-Benz              300-Class  1992  ...     18.0         617   2547.0
# 190  Mercedes-Benz              300-Class  1993  ...     18.0         617   2729.0
# 193  Mercedes-Benz              300-Class  1993  ...     14.0         617   2540.0
# 203       Chrysler                    300  2015  ...     18.0        1013  37570.0
# 204       Chrysler                    300  2015  ...     19.0        1013  31695.0
# 205       Chrysler                    300  2015  ...     19.0        1013  38070.0
# 206       Chrysler                    300  2015  ...     18.0        1013  44895.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].count()
# Out:
# Make                 888
# Model                888
# Year                 888
# Engine_Fuel_Type     888
# Engine_HP            888
# Engine_Cylinders     888
# Transmission_Type    888
# Driven_Wheels        888
# Number_of_Doors      888
# Market_Category        0
# Vehicle_Size         888
# Vehicle_Style        888
# highway_MPG          888
# city_mpg             888
# Popularity           888
# MSRP                 888
# dtype: int64

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3730
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Engine_HP <= 301) & (car_price1.Transmission_Type == 'AUTOMATIC')] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Engine_HP <= 301) & (car_price1.Transmission_Type == 'AUTOMATIC')].fillna('Luxury,Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3592
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.Market_Category.isnull().sum()
# Out:
# np.int64(3592)

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 1333       Ford         Aerostar  1995  ...     14.0        5657   2000.0
# 1334       Ford         Aerostar  1995  ...     15.0        5657   2000.0
# 1336       Ford         Aerostar  1996  ...     13.0        5657   2000.0
# 1337       Ford         Aerostar  1996  ...     15.0        5657   2000.0
# 1340       Ford         Aerostar  1997  ...     15.0        5657   2000.0
# 1341       Ford         Aerostar  1997  ...     13.0        5657   2000.0
# 1438     Nissan           Armada  2015  ...     13.0        2009  50780.0
# 1439     Nissan           Armada  2015  ...     12.0        2009  53680.0
# 1440     Nissan           Armada  2015  ...     12.0        2009  43810.0
# 1441     Nissan           Armada  2015  ...     12.0        2009  46500.0
# 1442     Nissan           Armada  2015  ...     13.0        2009  49880.0
# 1443     Nissan           Armada  2015  ...     13.0        2009  43600.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Passenger Minivan')].head(60)
# Out:
#             Make          Model  Year  ... city_mpg  Popularity     MSRP
# 1333        Ford       Aerostar  1995  ...     14.0        5657   2000.0
# 1334        Ford       Aerostar  1995  ...     15.0        5657   2000.0
# 1336        Ford       Aerostar  1996  ...     13.0        5657   2000.0
# 1337        Ford       Aerostar  1996  ...     15.0        5657   2000.0
# 1340        Ford       Aerostar  1997  ...     15.0        5657   2000.0
# 1341        Ford       Aerostar  1997  ...     13.0        5657   2000.0
# 1482   Chevrolet          Astro  2003  ...     12.0        1385  25690.0
# 1483   Chevrolet          Astro  2003  ...     14.0        1385  23690.0
# 1484   Chevrolet          Astro  2004  ...     12.0        1385  26195.0
# 1485   Chevrolet          Astro  2004  ...     14.0        1385  24195.0
# 1486   Chevrolet          Astro  2005  ...     14.0        1385  24430.0
# 1487   Chevrolet          Astro  2005  ...     12.0        1385  26430.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Passenger Minivan')] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Passenger Minivan')].fillna('Flex Fuel')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3485
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 1438     Nissan           Armada  2015  ...     13.0        2009  50780.0
# 1439     Nissan           Armada  2015  ...     12.0        2009  53680.0
# 1440     Nissan           Armada  2015  ...     12.0        2009  43810.0
# 1441     Nissan           Armada  2015  ...     12.0        2009  46500.0
# 1442     Nissan           Armada  2015  ...     13.0        2009  49880.0
# 1443     Nissan           Armada  2015  ...     13.0        2009  43600.0
# 1444     Nissan           Armada  2015  ...     13.0        2009  38510.0
# 1445     Nissan           Armada  2015  ...     12.0        2009  52780.0
# 1446     Nissan           Armada  2017  ...     14.0        2009  49650.0
# 1447     Nissan           Armada  2017  ...     14.0        2009  57590.0
# 1448     Nissan           Armada  2017  ...     13.0        2009  60490.0
# 1449     Nissan           Armada  2017  ...     13.0        2009  52550.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == '4dr SUV')]
# Out:
#          Make   Model  Year  ... city_mpg  Popularity     MSRP
# 1432   Nissan  Armada  2014  ...     13.0        2009  37590.0
# 1433   Nissan  Armada  2014  ...     12.0        2009  52860.0
# 1434   Nissan  Armada  2014  ...     13.0        2009  42680.0
# 1435   Nissan  Armada  2014  ...     12.0        2009  45580.0
# 1436   Nissan  Armada  2014  ...     12.0        2009  42890.0
# ...       ...     ...   ...  ...      ...         ...      ...
# 11876     GMC   Yukon  2017  ...     16.0         549  57315.0
# 11877     GMC   Yukon  2017  ...     16.0         549  51530.0
# 11878     GMC   Yukon  2017  ...     15.0         549  65965.0
# 11879     GMC   Yukon  2017  ...     16.0         549  60315.0
# 11880     GMC   Yukon  2017  ...     16.0         549  48530.0
#
# [501 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == '4dr SUV') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == '4dr SUV') & (car_price1.Market_Category.isnull())].fillna('Flex Fuel, Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3373
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 1476  Chevrolet      Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477  Chevrolet      Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478  Chevrolet      Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479  Chevrolet      Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480  Chevrolet      Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481  Chevrolet      Astro Cargo  2005  ...     14.0        1385  25430.0
# 2311  Chevrolet          Caprice  1994  ...     15.0        1385   2000.0
# 2315  Chevrolet          Caprice  1995  ...     15.0        1385   2000.0
# 2316  Chevrolet          Caprice  1996  ...     15.0        1385   2000.0
# 2331      Dodge          Caravan  2005  ...     17.0        1851  19835.0
# 2509  Chevrolet        Chevy Van  1996  ...     14.0        1385   2000.0
# 2510  Chevrolet        Chevy Van  1997  ...     14.0        1385   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Minivan')].head(60)
# Out:
#                Make         Model  Year  ... city_mpg  Popularity     MSRP
# 1476      Chevrolet   Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477      Chevrolet   Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478      Chevrolet   Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479      Chevrolet   Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480      Chevrolet   Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481      Chevrolet   Astro Cargo  2005  ...     14.0        1385  25430.0
# 2331          Dodge       Caravan  2005  ...     17.0        1851  19835.0
# 2333          Dodge       Caravan  2006  ...     17.0        1851  20130.0
# 6793  Mercedes-Benz        Metris  2016  ...     21.0         617  28950.0
# 8953            GMC  Safari Cargo  2003  ...     14.0         549  24450.0
# 8954            GMC  Safari Cargo  2003  ...     15.0         549  22050.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Engine_Fuel_Type == 'regular unleaded')].fillna('Flex Fuel')
# Out:
#            Make         Model  Year  ... city_mpg  Popularity     MSRP
# 1476  Chevrolet   Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477  Chevrolet   Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478  Chevrolet   Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479  Chevrolet   Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480  Chevrolet   Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481  Chevrolet   Astro Cargo  2005  ...     14.0        1385  25430.0
# 2331      Dodge       Caravan  2005  ...     17.0        1851  19835.0
# 2333      Dodge       Caravan  2006  ...     17.0        1851  20130.0
# 8953        GMC  Safari Cargo  2003  ...     14.0         549  24450.0
# 8954        GMC  Safari Cargo  2003  ...     15.0         549  22050.0
# 8955        GMC  Safari Cargo  2004  ...     14.0         549  22695.0
# 8956        GMC  Safari Cargo  2004  ...     14.0         549  25195.0
# ...

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3373
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Engine_Fuel_Type == 'premium unleaded (required)')].fillna('Flex Fuel')
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 1476  Chevrolet      Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477  Chevrolet      Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478  Chevrolet      Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479  Chevrolet      Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480  Chevrolet      Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481  Chevrolet      Astro Cargo  2005  ...     14.0        1385  25430.0
# 2311  Chevrolet          Caprice  1994  ...     15.0        1385   2000.0
# 2315  Chevrolet          Caprice  1995  ...     15.0        1385   2000.0
# 2316  Chevrolet          Caprice  1996  ...     15.0        1385   2000.0
# 2331      Dodge          Caravan  2005  ...     17.0        1851  19835.0
# 2509  Chevrolet        Chevy Van  1996  ...     14.0        1385   2000.0
# 2510  Chevrolet        Chevy Van  1997  ...     14.0        1385   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Extended Cab Pickup')].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 2615  Chevrolet  C/K 1500 Series  1997  ...     14.0        1385   2668.0
# 2617  Chevrolet  C/K 1500 Series  1997  ...     15.0        1385   2637.0
# 2618  Chevrolet  C/K 1500 Series  1997  ...     15.0        1385   2517.0
# 2619  Chevrolet  C/K 1500 Series  1997  ...     11.0        1385   3046.0
# 2621  Chevrolet  C/K 1500 Series  1997  ...     14.0        1385   3046.0
# 2622  Chevrolet  C/K 1500 Series  1997  ...     15.0        1385   2896.0
# 2623  Chevrolet  C/K 1500 Series  1997  ...     14.0        1385   2891.0
# 2624  Chevrolet  C/K 1500 Series  1997  ...     15.0        1385   2713.0
# 2625  Chevrolet  C/K 1500 Series  1997  ...     11.0        1385   3120.0
# 2631  Chevrolet  C/K 1500 Series  1997  ...     14.0        1385   2925.0
# 2634  Chevrolet  C/K 1500 Series  1997  ...     14.0        1385   3088.0
# 2636  Chevrolet  C/K 1500 Series  1997  ...     14.0        1385   3220.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Market_Category.isnull())].fillna('Flex Fuel')

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Market_Category.isnull())].fillna('Flex Fuel')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3073
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Wagon')]
# Out:
#              Make           Model  Year  ... city_mpg  Popularity     MSRP
# 2311    Chevrolet         Caprice  1994  ...     15.0        1385   2000.0
# 2315    Chevrolet         Caprice  1995  ...     15.0        1385   2000.0
# 2316    Chevrolet         Caprice  1996  ...     15.0        1385   2000.0
# 3295   Oldsmobile  Custom Cruiser  1990  ...     15.0          26   2000.0
# 3296   Oldsmobile  Custom Cruiser  1991  ...     15.0          26   2000.0
# ...           ...             ...   ...  ...      ...         ...      ...
# 10279        Ford        Taurus X  2009  ...     15.0        5657  33180.0
# 10280        Ford        Taurus X  2009  ...     15.0        5657  34175.0
# 10281        Ford        Taurus X  2009  ...     17.0        5657  31330.0
# 10282        Ford        Taurus X  2009  ...     15.0        5657  30120.0
# 10283        Ford        Taurus X  2009  ...     17.0        5657  28270.0
#
# [104 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())].fillna('Crossover, Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3044
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 1476  Chevrolet      Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477  Chevrolet      Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478  Chevrolet      Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479  Chevrolet      Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480  Chevrolet      Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481  Chevrolet      Astro Cargo  2005  ...     14.0        1385  25430.0
# 2331      Dodge          Caravan  2005  ...     17.0        1851  19835.0
# 2509  Chevrolet        Chevy Van  1996  ...     14.0        1385   2000.0
# 2510  Chevrolet        Chevy Van  1997  ...     14.0        1385   2000.0
# 2515  Chevrolet        Chevy Van  1998  ...     13.0        1385   2116.0
# 3657       Ford            E-250  1996  ...     11.0        5657   2000.0
# 3659       Ford            E-250  1996  ...     11.0        5657   2000.0
# ...

# %%
car_price1.Market_Category.isnull().sum()
# Out:
# np.int64(3044)

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3044
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#            Make            Model  Year  ... city_mpg  Popularity     MSRP
# 1476  Chevrolet      Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477  Chevrolet      Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478  Chevrolet      Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479  Chevrolet      Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480  Chevrolet      Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481  Chevrolet      Astro Cargo  2005  ...     14.0        1385  25430.0
# 2331      Dodge          Caravan  2005  ...     17.0        1851  19835.0
# 2509  Chevrolet        Chevy Van  1996  ...     14.0        1385   2000.0
# 2510  Chevrolet        Chevy Van  1997  ...     14.0        1385   2000.0
# 2515  Chevrolet        Chevy Van  1998  ...     13.0        1385   2116.0
# 3657       Ford            E-250  1996  ...     11.0        5657   2000.0
# 3659       Ford            E-250  1996  ...     11.0        5657   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Minivan')].head(60)
# Out:
#                Make         Model  Year  ... city_mpg  Popularity     MSRP
# 1476      Chevrolet   Astro Cargo  2003  ...     15.0        1385  22050.0
# 1477      Chevrolet   Astro Cargo  2003  ...     14.0        1385  24450.0
# 1478      Chevrolet   Astro Cargo  2004  ...     14.0        1385  25195.0
# 1479      Chevrolet   Astro Cargo  2004  ...     14.0        1385  22695.0
# 1480      Chevrolet   Astro Cargo  2005  ...     15.0        1385  22930.0
# 1481      Chevrolet   Astro Cargo  2005  ...     14.0        1385  25430.0
# 2331          Dodge       Caravan  2005  ...     17.0        1851  19835.0
# 2333          Dodge       Caravan  2006  ...     17.0        1851  20130.0
# 6793  Mercedes-Benz        Metris  2016  ...     21.0         617  28950.0
# 8953            GMC  Safari Cargo  2003  ...     14.0         549  24450.0
# 8954            GMC  Safari Cargo  2003  ...     15.0         549  22050.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Market_Category.isnull())].fillna('Flex Fuel, Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      3031
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Crew Cab Pickup')].head(60)
# Out:
#            Make                    Model  Year  ... city_mpg  Popularity     MSRP
# 1571  Chevrolet                Avalanche  2010  ...     15.0        1385  45815.0
# 1572  Chevrolet                Avalanche  2010  ...     15.0        1385  35725.0
# 1573  Chevrolet                Avalanche  2010  ...     15.0        1385  38830.0
# 1574  Chevrolet                Avalanche  2011  ...     15.0        1385  39405.0
# 1575  Chevrolet                Avalanche  2011  ...     15.0        1385  46195.0
# 1576  Chevrolet                Avalanche  2011  ...     15.0        1385  39350.0
# 1577  Chevrolet                Avalanche  2011  ...     15.0        1385  49500.0
# 1578  Chevrolet                Avalanche  2011  ...     15.0        1385  42455.0
# 1579  Chevrolet                Avalanche  2011  ...     15.0        1385  36300.0
# 1580  Chevrolet                Avalanche  2012  ...     15.0        1385  40195.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Market_Category.isnull())].fillna('Crossover, Flex Fuel')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2874
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2874
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())]
# Out:
#              Make        Model  Year  ... city_mpg  Popularity     MSRP
# 2509    Chevrolet    Chevy Van  1996  ...     14.0        1385   2000.0
# 2510    Chevrolet    Chevy Van  1997  ...     14.0        1385   2000.0
# 2515    Chevrolet    Chevy Van  1998  ...     13.0        1385   2116.0
# 3657         Ford        E-250  1996  ...     11.0        5657   2000.0
# 3659         Ford        E-250  1996  ...     11.0        5657   2000.0
# 3661         Ford        E-250  1997  ...     12.0        5657   2000.0
# 3662         Ford        E-250  1997  ...     12.0        5657   2000.0
# 3666         Ford        E-250  1998  ...     13.0        5657   2107.0
# 8036          GMC  Rally Wagon  1994  ...     11.0         549   2000.0
# 8129        Dodge    Ram Cargo  2001  ...     12.0        1851  22305.0
# 8130        Dodge    Ram Cargo  2001  ...     13.0        1851  20850.0
# 8131        Dodge    Ram Cargo  2002  ...     12.0        1851  22885.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Coupe')].sort_values('Engine_HP').head(60)
# Out:
#                 Make        Model  Year  ... city_mpg  Popularity      MSRP
# 10510     Oldsmobile     Toronado  1990  ...     16.0          26    2000.0
# 10511     Oldsmobile     Toronado  1990  ...     16.0          26    2000.0
# 10512     Oldsmobile     Toronado  1991  ...     16.0          26    2000.0
# 10513     Oldsmobile     Toronado  1991  ...     16.0          26    2000.0
# 10514     Oldsmobile     Toronado  1992  ...     16.0          26    2000.0
# 10515     Oldsmobile     Toronado  1992  ...     16.0          26    2000.0
# 8531           Buick      Riviera  1997  ...     17.0         155    2000.0
# 6708         Lincoln     Mark VII  1991  ...     15.0          61    2000.0
# 6706         Lincoln     Mark VII  1990  ...     15.0          61    2000.0
# 6711         Lincoln     Mark VII  1992  ...     15.0          61    2000.0
# 6707         Lincoln     Mark VII  1990  ...     15.0          61    2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Market_Category.isnull())].fillna('Luxury')

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan')].head(60)
# Out:
#          Make     Model  Year  ... city_mpg  Popularity     MSRP
# 17       Audi       100  1992  ...     17.0        3105   2000.0
# 18       Audi       100  1992  ...     17.0        3105   2000.0
# 20       Audi       100  1992  ...     17.0        3105   2000.0
# 21       Audi       100  1992  ...     16.0        3105   2000.0
# 22       Audi       100  1993  ...     17.0        3105   2000.0
# 24       Audi       100  1993  ...     17.0        3105   2000.0
# 25       Audi       100  1993  ...     17.0        3105   2000.0
# 26       Audi       100  1993  ...     16.0        3105   2000.0
# 28       Audi       100  1994  ...     16.0        3105   2000.0
# 29       Audi       100  1994  ...     17.0        3105   2000.0
# 30       Audi       100  1994  ...     16.0        3105   2000.0
# 58       Audi       200  1990  ...     16.0        3105   2000.0
# 60       Audi       200  1990  ...     15.0        3105   2000.0
# ...

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11911 non-null  object
#  4   Engine_HP          11846 non-null  float64
#  5   Engine_Cylinders   11914 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11914 non-null  int64
#  9   Market_Category    9050 non-null   object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Market_Category.isnull())]
# Out:
#             Make        Model  Year  ... city_mpg  Popularity     MSRP
# 2509   Chevrolet    Chevy Van  1996  ...     14.0        1385   2000.0
# 2510   Chevrolet    Chevy Van  1997  ...     14.0        1385   2000.0
# 2515   Chevrolet    Chevy Van  1998  ...     13.0        1385   2116.0
# 3657        Ford        E-250  1996  ...     11.0        5657   2000.0
# 3659        Ford        E-250  1996  ...     11.0        5657   2000.0
# 3661        Ford        E-250  1997  ...     12.0        5657   2000.0
# 3662        Ford        E-250  1997  ...     12.0        5657   2000.0
# 3666        Ford        E-250  1998  ...     13.0        5657   2107.0
# 8036         GMC  Rally Wagon  1994  ...     11.0         549   2000.0
# 8129       Dodge    Ram Cargo  2001  ...     12.0        1851  22305.0
# 8130       Dodge    Ram Cargo  2001  ...     13.0        1851  20850.0
# 8131       Dodge    Ram Cargo  2002  ...     12.0        1851  22885.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Market_Category.isnull())].fillna('Crossover, Performance')

# %%
car_price1.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2845
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Large') & (car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Market_Category.isnull())].fillna('Crossover, Performance')

# %%
car_price1.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2842
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1.Engine_HP = car_price1.Engine_HP.fillna(car_price1.Engine_HP.mode(0))

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Engine_HP <= 220)].sort_values('Engine_HP', ascending = False).head(60)
# Out:
#                 Make           Model  Year  ... city_mpg  Popularity     MSRP
# 10898           Audi              TT  2017  ...     23.0        3105  43500.0
# 10097         Toyota           Supra  1996  ...     16.0        2031  14977.0
# 10099         Toyota           Supra  1997  ...     16.0        2031  17320.0
# 10895           Audi              TT  2016  ...     23.0        3105  42900.0
# 3090        Chrysler       Crossfire  2006  ...     15.0        1013  29145.0
# 3093        Chrysler       Crossfire  2006  ...     15.0        1013  34195.0
# 8703           Mazda            RX-8  2009  ...     16.0         586  31700.0
# 8699           Mazda            RX-8  2009  ...     16.0         586  26435.0
# 8706           Mazda            RX-8  2010  ...     16.0         586  26645.0
# 8714           Mazda            RX-8  2011  ...     16.0         586  26795.0
# 8704           Mazda            RX-8  2009  ...     16.0         586  28560.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Market_Category.isnull())].sort_values('Engine_HP').head(60)
# Out:
#              Make           Model  Year  ... city_mpg  Popularity     MSRP
# 6383      Pontiac         Le Mans  1993  ...     24.0         210   2000.0
# 6384      Pontiac         Le Mans  1993  ...     26.0         210   2000.0
# 6377      Pontiac         Le Mans  1991  ...     27.0         210   2000.0
# 6379      Pontiac         Le Mans  1992  ...     24.0         210   2000.0
# 6376      Pontiac         Le Mans  1991  ...     25.0         210   2000.0
# 6381      Pontiac         Le Mans  1992  ...     26.0         210   2000.0
# 4888   Volkswagen             Fox  1992  ...     22.0         873   2000.0
# 4887   Volkswagen             Fox  1991  ...     22.0         873   2000.0
# 4891   Volkswagen             Fox  1993  ...     22.0         873   2000.0
# 4890   Volkswagen             Fox  1993  ...     22.0         873   2000.0
# 7749       Nissan          Pulsar  1990  ...     23.0        2009   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Engine_HP <= 220) & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Engine_HP <= 220) & (car_price1.Market_Category.isnull())].fillna('Performance')

# %%
car_price1.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2686
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Coupe') & (car_price1.Market_Category.isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())].Vehicle_Style.unique()
# Out:
# array(['Sedan', 'Convertible', 'Wagon', 'Passenger Minivan',
#        'Regular Cab Pickup', 'Extended Cab Pickup', '2dr SUV',
#        'Crew Cab Pickup', 'Cargo Minivan', 'Passenger Van', 'Cargo Van',
#        'Convertible SUV', '4dr SUV'], dtype=object)

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].Market_Category.isna().sum()
# Out:
# np.int64(409)

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'diesel') & (car_price1.Market_Category.isnull())].head(60)
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Popularity <= 586)].head(60)
# Out:
#             Make           Model  Year  ... city_mpg  Popularity     MSRP
# 358        Mazda               3  2015  ...     25.0         586  25045.0
# 359        Mazda               3  2015  ...     28.0         586  26095.0
# 360        Mazda               3  2015  ...     30.0         586  23795.0
# 361        Mazda               3  2015  ...     29.0         586  19595.0
# 362        Mazda               3  2015  ...     29.0         586  18445.0
# 363        Mazda               3  2015  ...     25.0         586  23845.0
# 365        Mazda               3  2015  ...     28.0         586  24895.0
# 368        Mazda               3  2015  ...     30.0         586  19495.0
# 373        Mazda               3  2015  ...     29.0         586  16945.0
# 375        Mazda               3  2015  ...     30.0         586  20645.0
# 378        Mazda               3  2015  ...     29.0         586  22745.0
# 379        Mazda               3  2015  ...     30.0         586  17995.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Popularity <= 586)] = car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Popularity <= 586)].fillna('Performance')

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Popularity >= 586)] = car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Popularity >= 586)].fillna('Luxury')

# %%
car_price1.isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2277
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].Market_Category.isna().sum()
# Out:
# np.int64(0)

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())]
# Out:
#         Make Model  Year  ... city_mpg  Popularity     MSRP
# 545     FIAT   500  2015  ...     28.0         819  22800.0
# 546     FIAT   500  2015  ...     28.0         819  24700.0
# 549     FIAT   500  2015  ...     28.0         819  20345.0
# 558     FIAT   500  2016  ...     31.0         819  24495.0
# 560     FIAT   500  2016  ...     31.0         819  20395.0
# ...      ...   ...   ...  ...      ...         ...      ...
# 11546  Scion    xB  2014  ...     22.0         105  20420.0
# 11547  Scion    xB  2014  ...     22.0         105  17920.0
# 11548  Scion    xB  2015  ...     22.0         105  18070.0
# 11549  Scion    xB  2015  ...     22.0         105  19685.0
# 11550  Scion    xB  2015  ...     22.0         105  17120.0
#
# [1109 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Market_Category.isnull())].Market_Category.isna().sum()
# Out:
# np.int64(99)

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible')].Market_Category.isnull().sum()
# Out:
# np.int64(99)

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible')].sort_values('Engine_HP').head(60)
# Out:
#              Make               Model  Year  ... city_mpg  Popularity     MSRP
# 7448       Toyota               Paseo  1997  ...     25.0        2031   2178.0
# 2125   Volkswagen           Cabriolet  1992  ...     22.0         873   2000.0
# 2123   Volkswagen           Cabriolet  1992  ...     22.0         873   2000.0
# 2126   Volkswagen           Cabriolet  1993  ...     21.0         873   2000.0
# 2124   Volkswagen           Cabriolet  1992  ...     22.0         873   2000.0
# 2127   Volkswagen           Cabriolet  1993  ...     21.0         873   2000.0
# 2122   Volkswagen           Cabriolet  1991  ...     22.0         873   2000.0
# 6368     Chrysler            Le Baron  1993  ...     18.0        1013   2000.0
# 9147        Dodge              Shadow  1992  ...     20.0        1851   2000.0
# 9163        Dodge              Shadow  1993  ...     22.0        1851   2000.0
# 9161        Dodge              Shadow  1993  ...     22.0        1851   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#             Make               Model  Year  ... city_mpg  Popularity     MSRP
# 545         FIAT                 500  2015  ...     28.0         819  22800.0
# 546         FIAT                 500  2015  ...     28.0         819  24700.0
# 549         FIAT                 500  2015  ...     28.0         819  20345.0
# 558         FIAT                 500  2016  ...     31.0         819  24495.0
# 560         FIAT                 500  2016  ...     31.0         819  20395.0
# 563         FIAT                 500  2016  ...     31.0         819  21395.0
# 566         FIAT                 500  2017  ...     27.0         819  17485.0
# 567         FIAT                 500  2017  ...     27.0         819  20885.0
# 1792  Volkswagen  Beetle Convertible  2014  ...     24.0         873  27295.0
# 1795  Volkswagen  Beetle Convertible  2014  ...     21.0         873  27295.0
# 1798  Volkswagen  Beetle Convertible  2014  ...     24.0         873  29395.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible')].Market_Category.unique()
# Out:
# array(['Luxury,Performance', 'Luxury', 'Luxury,High-Performance',
#        'Performance', 'Factory Tuner,Luxury,High-Performance',
#        'High-Performance', 'Exotic,High-Performance',
#        'Factory Tuner,Performance', nan, 'Flex Fuel,Luxury',
#        'Exotic,Factory Tuner,Luxury,High-Performance', 'Diesel',
#        'Exotic,Luxury,High-Performance', 'Factory Tuner,High-Performance',
#        'Exotic,Factory Tuner,High-Performance',
#        'Factory Tuner,Luxury,Performance'], dtype=object)

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Engine_HP <= 140) & (car_price1.Market_Category.isnull())]
# Out:
#              Make      Model  Year  ... city_mpg  Popularity     MSRP
# 545          FIAT        500  2015  ...     28.0         819  22800.0
# 546          FIAT        500  2015  ...     28.0         819  24700.0
# 549          FIAT        500  2015  ...     28.0         819  20345.0
# 558          FIAT        500  2016  ...     31.0         819  24495.0
# 560          FIAT        500  2016  ...     31.0         819  20395.0
# 563          FIAT        500  2016  ...     31.0         819  21395.0
# 566          FIAT        500  2017  ...     27.0         819  17485.0
# 567          FIAT        500  2017  ...     27.0         819  20885.0
# 2122   Volkswagen  Cabriolet  1991  ...     22.0         873   2000.0
# 2123   Volkswagen  Cabriolet  1992  ...     22.0         873   2000.0
# 2124   Volkswagen  Cabriolet  1992  ...     22.0         873   2000.0
# 2125   Volkswagen  Cabriolet  1992  ...     22.0         873   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Engine_HP <= 140) & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Engine_HP <= 140) & (car_price1.Market_Category.isnull())].fillna('Convertible, Performance')

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Engine_HP >= 140) & (car_price1.Market_Category.isnull())].sort_values('Engine_HP', ascending = False).head(60)
# Out:
#             Make               Model  Year  ... city_mpg  Popularity     MSRP
# 4029  Volkswagen                 Eos  2015  ...     22.0         873  42745.0
# 4030  Volkswagen                 Eos  2015  ...     22.0         873  36145.0
# 4031  Volkswagen                 Eos  2016  ...     22.0         873  31995.0
# 4028  Volkswagen                 Eos  2015  ...     22.0         873  39545.0
# 4026  Volkswagen                 Eos  2014  ...     22.0         873  42095.0
# 4025  Volkswagen                 Eos  2014  ...     22.0         873  38325.0
# 4027  Volkswagen                 Eos  2014  ...     22.0         873  35595.0
# 1807  Volkswagen  Beetle Convertible  2014  ...     24.0         873  27295.0
# 1792  Volkswagen  Beetle Convertible  2014  ...     24.0         873  27295.0
# 1795  Volkswagen  Beetle Convertible  2014  ...     21.0         873  27295.0
# 1798  Volkswagen  Beetle Convertible  2014  ...     24.0         873  29395.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Engine_HP >= 140) & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Engine_HP >= 140) & (car_price1.Market_Category.isnull())].fillna('Convertible, Luxury')

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Convertible') & (car_price1.Market_Category.isnull())]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1.isnull().sum()
#car_price1.info()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              68
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      2178
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())].isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        0
# Engine_HP               5
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1010
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Wagon')].sort_values('Engine_HP', ascending = False).head(60)
# Out:
#              Make             Model  Year  ... city_mpg  Popularity     MSRP
# 825          Saab               9-3  2009  ...     15.0         376  44885.0
# 5717    Chevrolet               HHR  2010  ...     21.0        1385  26255.0
# 5710    Chevrolet               HHR  2009  ...     21.0        1385  25135.0
# 5712    Chevrolet               HHR  2009  ...     21.0        1385  24815.0
# 802          Saab              9-2X  2006  ...     18.0         376  26950.0
# 11114       Volvo               V50  2011  ...     21.0         870  29000.0
# 11110       Volvo               V50  2009  ...     18.0         870  35500.0
# 11113       Volvo               V50  2011  ...     21.0         870  32850.0
# 800          Saab              9-2X  2005  ...     17.0         376  26950.0
# 11111       Volvo               V50  2010  ...     20.0         870  33050.0
# 820          Saab       9-3 Griffin  2012  ...     20.0         376  29830.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())].sort_values('Engine_HP', ascending = True).head(60)
# Out:
#            Make     Model  Year  ... city_mpg  Popularity     MSRP
# 6446     Subaru    Loyale  1993  ...     22.0         640   2000.0
# 6447     Subaru    Loyale  1993  ...     21.0         640   2000.0
# 6442     Subaru    Loyale  1992  ...     22.0         640   2000.0
# 6450     Subaru    Loyale  1994  ...     21.0         640   2000.0
# 6444     Subaru    Loyale  1992  ...     21.0         640   2000.0
# 2833   Plymouth      Colt  1994  ...     21.0         535   2000.0
# 2821   Plymouth      Colt  1992  ...     21.0         535   2000.0
# 2832   Plymouth      Colt  1993  ...     21.0         535   2000.0
# 2825   Plymouth      Colt  1992  ...     19.0         535   2000.0
# 2828   Plymouth      Colt  1993  ...     19.0         535   2000.0
# 2824   Plymouth      Colt  1992  ...     21.0         535   2000.0
# 3288     Nissan      Cube  2012  ...     27.0        2009  17580.0
# 4222     Suzuki    Esteem  2000  ...     24.0         481   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())].fillna('Luxury, Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\955944542.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '[160.0 160.0 160.0 160.0 160.0 160.0 160.0 160.0 160.0 160.0 160.0 160.0
#  160.0 155.0 155.0 155.0 155.0 155.0 155.0 155.0 155.0 155.0 155.0 155.0
#  155.0 158.0 172.0 158.0 158.0 158.0 158.0 158.0 172.0 158.0 158.0 158.0
#  172.0 158.0 158.0 158.0 158.0 113.0 113.0 113.0 113.0 136.0 113.0 113.0
#  136.0 136.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0
#  122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0 122.0
#  122.0 122.0 122.0 122.0 126.0 126.0 126.0 126.0 127.0 127.0 127.0 127.0
#  127.0 127.0 127.0 127.0 127.0 127.0 127.0 127.0 127.0 170.0 170.0 170.0
#  170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0
#  170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0 170.0
# ...

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              63
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1985
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')].sort_values('Engine_HP', ascending = True).head(60)
# Out:
#              Make              Model  Year  ... city_mpg Popularity    MSRP
# 8965       Suzuki            Samurai  1993  ...     24.0        481  2000.0
# 8966       Suzuki            Samurai  1993  ...     24.0        481  2000.0
# 8967       Suzuki            Samurai  1994  ...     24.0        481  2000.0
# 8968       Suzuki            Samurai  1995  ...     24.0        481  2000.0
# 11481      Suzuki               X-90  1998  ...     22.0        481  2000.0
# 9180       Suzuki           Sidekick  1996  ...     21.0        481  2000.0
# 9181       Suzuki           Sidekick  1996  ...     21.0        481  2000.0
# 9182       Suzuki           Sidekick  1996  ...     21.0        481  2000.0
# 9183       Suzuki           Sidekick  1996  ...     21.0        481  2000.0
# 9185       Suzuki           Sidekick  1997  ...     21.0        481  2000.0
# 9187       Suzuki           Sidekick  1997  ...     21.0        481  2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')].sort_values('Engine_HP', ascending = True).head(60)
# Out:
#              Make               Model  Year  ... city_mpg Popularity     MSRP
# 8965       Suzuki             Samurai  1993  ...     24.0        481   2000.0
# 8966       Suzuki             Samurai  1993  ...     24.0        481   2000.0
# 8967       Suzuki             Samurai  1994  ...     24.0        481   2000.0
# 8968       Suzuki             Samurai  1995  ...     24.0        481   2000.0
# 9197       Suzuki            Sidekick  1998  ...     21.0        481   2000.0
# 9199       Suzuki            Sidekick  1998  ...     21.0        481   2000.0
# 9192       Suzuki            Sidekick  1998  ...     21.0        481   2000.0
# 9191       Suzuki            Sidekick  1997  ...     21.0        481   2000.0
# 9189       Suzuki            Sidekick  1997  ...     21.0        481   2000.0
# 9182       Suzuki            Sidekick  1996  ...     21.0        481   2000.0
# 9181       Suzuki            Sidekick  1996  ...     21.0        481   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')].isna().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine_Fuel_Type      0
# Engine_HP             0
# Engine_Cylinders      0
# Transmission_Type     0
# Driven_Wheels         0
# Number_of_Doors       0
# Market_Category      23
# Vehicle_Size          0
# Vehicle_Style         0
# highway_MPG           0
# city_mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')].fillna('Crossover, Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\2836574156.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')].fillna('Crossover, Performance')

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact')].Market_Category.unique()
# Out:
# array(['Factory Tuner,Luxury,High-Performance', 'Luxury,Performance',
#        'Luxury,High-Performance', 'Luxury', 'Performance', 'Hatchback',
#        'Hatchback,Performance', 'Hatchback,Factory Tuner,Performance',
#        'High-Performance', 'Factory Tuner,High-Performance',
#        'Exotic,High-Performance', 'Exotic,Factory Tuner,High-Performance',
#        'Factory Tuner,Performance', 'Convertible, Performance',
#        'Luxury, Performance', 'Crossover', nan, 'Flex Fuel,Luxury',
#        'Hatchback,Luxury,Performance', 'Hatchback,Luxury',
#        'Diesel,Luxury', 'Exotic,Factory Tuner,Luxury,High-Performance',
#        'Flex Fuel,Luxury,High-Performance', 'Flex Fuel',
#        'Convertible, Luxury', 'Diesel', 'Hatchback,Diesel', 'Hybrid',
#        'Factory Tuner,Luxury,Performance',
#        'Exotic,Luxury,High-Performance',
#        'Hatchback,Factory Tuner,Luxury,Performance', 'Hatchback,Hybrid',
#        'Crossover,Hybrid', 'Hatchback,Luxury,Hybrid',
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible SUV') & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#              Make               Model  Year  ... city_mpg Popularity     MSRP
# 3553   Land Rover            Defender  1997  ...     12.0        258  36931.0
# 8265   Land Rover  Range Rover Evoque  2017  ...     20.0        258  57700.0
# 8267   Land Rover  Range Rover Evoque  2017  ...     20.0        258  51100.0
# 8965       Suzuki             Samurai  1993  ...     24.0        481   2000.0
# 8966       Suzuki             Samurai  1993  ...     24.0        481   2000.0
# 8967       Suzuki             Samurai  1994  ...     24.0        481   2000.0
# 8968       Suzuki             Samurai  1995  ...     24.0        481   2000.0
# 9181       Suzuki            Sidekick  1996  ...     21.0        481   2000.0
# 9182       Suzuki            Sidekick  1996  ...     21.0        481   2000.0
# 9189       Suzuki            Sidekick  1997  ...     21.0        481   2000.0
# 9191       Suzuki            Sidekick  1997  ...     21.0        481   2000.0
# ...

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              63
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1962
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')].sort_values('Engine_HP', ascending = True).head(60)
# Out:
#              Make              Model  Year  ... city_mpg Popularity    MSRP
# 11482      Suzuki               X-90  1998  ...     22.0        481  2000.0
# 9193       Suzuki           Sidekick  1998  ...     20.0        481  2000.0
# 9187       Suzuki           Sidekick  1997  ...     21.0        481  2000.0
# 9185       Suzuki           Sidekick  1997  ...     21.0        481  2000.0
# 9183       Suzuki           Sidekick  1996  ...     21.0        481  2000.0
# 9180       Suzuki           Sidekick  1996  ...     21.0        481  2000.0
# 9194       Suzuki           Sidekick  1998  ...     19.0        481  2107.0
# 9198       Suzuki           Sidekick  1998  ...     20.0        481  2019.0
# 11481      Suzuki               X-90  1998  ...     22.0        481  2000.0
# 11476      Suzuki               X-90  1996  ...     22.0        481  2000.0
# 11477      Suzuki               X-90  1996  ...     22.0        481  2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].sort_values('Engine_HP', ascending = True).head(60)
# Out:
#              Make              Model  Year  ... city_mpg Popularity     MSRP
# 8800          GMC               S-15  1990  ...     21.0        549   2000.0
# 8804          GMC               S-15  1990  ...     21.0        549   2000.0
# 8805          GMC               S-15  1990  ...     21.0        549   2000.0
# 8810          GMC               S-15  1990  ...     21.0        549   2000.0
# 8812          GMC               S-15  1990  ...     21.0        549   2000.0
# 8813          GMC               S-15  1990  ...     21.0        549   2000.0
# 8799          GMC               S-15  1990  ...     21.0        549   2000.0
# 8121        Dodge      Ram 50 Pickup  1992  ...     17.0       1851   2000.0
# 7587       Toyota             Pickup  1995  ...     19.0       2031   2000.0
# 8111        Dodge      Ram 50 Pickup  1991  ...     17.0       1851   2000.0
# 7585       Toyota             Pickup  1995  ...     17.0       2031   2409.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1195659767.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Regular Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')

# %%
car_price1[(car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].sort_values('Engine_HP', ascending = True).head(60)
# Out:
#             Make            Model  Year  ... city_mpg Popularity     MSRP
# 8802         GMC             S-15  1990  ...     21.0        549   2000.0
# 8806         GMC             S-15  1990  ...     21.0        549   2000.0
# 8803         GMC             S-15  1990  ...     21.0        549   2000.0
# 7576      Toyota           Pickup  1994  ...     19.0       2031   2000.0
# 7571      Toyota           Pickup  1994  ...     17.0       2031   2293.0
# 8107       Dodge    Ram 50 Pickup  1991  ...     17.0       1851   2000.0
# 8114       Dodge    Ram 50 Pickup  1991  ...     17.0       1851   2000.0
# 7569      Toyota           Pickup  1993  ...     17.0       2031   2142.0
# 7583      Toyota           Pickup  1995  ...     19.0       2031   2197.0
# 7584      Toyota           Pickup  1995  ...     17.0       2031   2553.0
# 1711       Mazda  B-Series Pickup  2000  ...     20.0        586   2961.0
# 1689       Mazda  B-Series Pickup  1998  ...     19.0        586   2717.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\4064660434.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Extended Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              63
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1614
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#             Make   Model  Year  ... city_mpg Popularity     MSRP
# 1969   Chevrolet  Blazer  2003  ...     14.0       1385  20745.0
# 1970   Chevrolet  Blazer  2003  ...     13.0       1385  23745.0
# 1973   Chevrolet  Blazer  2003  ...     14.0       1385  22845.0
# 1976   Chevrolet  Blazer  2004  ...     13.0       1385  24055.0
# 1977   Chevrolet  Blazer  2004  ...     14.0       1385  23255.0
# ...          ...     ...   ...  ...      ...        ...      ...
# 11478     Suzuki    X-90  1997  ...     22.0        481   2000.0
# 11479     Suzuki    X-90  1997  ...     22.0        481   2000.0
# 11480     Suzuki    X-90  1998  ...     22.0        481   2000.0
# 11481     Suzuki    X-90  1998  ...     22.0        481   2000.0
# 11482     Suzuki    X-90  1998  ...     22.0        481   2000.0
#
# [89 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact')].isna().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine_Fuel_Type      0
# Engine_HP             0
# Engine_Cylinders      0
# Transmission_Type     0
# Driven_Wheels         0
# Number_of_Doors       0
# Market_Category      75
# Vehicle_Size          0
# Vehicle_Style         0
# highway_MPG           0
# city_mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact')].head(60)
# Out:
#             Make               Model  Year  ... city_mpg Popularity     MSRP
# 1969   Chevrolet              Blazer  2003  ...     14.0       1385  20745.0
# 1970   Chevrolet              Blazer  2003  ...     13.0       1385  23745.0
# 1973   Chevrolet              Blazer  2003  ...     14.0       1385  22845.0
# 1976   Chevrolet              Blazer  2004  ...     13.0       1385  24055.0
# 1977   Chevrolet              Blazer  2004  ...     14.0       1385  23255.0
# 1978   Chevrolet              Blazer  2004  ...     14.0       1385  21055.0
# 1979   Chevrolet              Blazer  2005  ...     13.0       1385  24305.0
# 1980   Chevrolet              Blazer  2005  ...     14.0       1385  21305.0
# 2023        Ford           Bronco II  1990  ...     16.0       5657   2000.0
# 2024        Ford           Bronco II  1990  ...     16.0       5657   2000.0
# 2025        Ford           Bronco II  1990  ...     15.0       5657   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())].fillna('Crossover, Luxury')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\4280219204.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())].fillna('Crossover, Luxury')

# %%
car_price1[(car_price1.Vehicle_Style == '4dr SUV') & (car_price1.Vehicle_Size == 'Compact')].head(60)
# Out:
#         Make      Model  Year  ... city_mpg Popularity     MSRP
# 583     FIAT       500X  2016  ...     21.0        819  24635.0
# 584     FIAT       500X  2016  ...     22.0        819  25135.0
# 585     FIAT       500X  2016  ...     21.0        819  29235.0
# 586     FIAT       500X  2016  ...     22.0        819  23335.0
# 587     FIAT       500X  2016  ...     22.0        819  22735.0
# 588     FIAT       500X  2016  ...     21.0        819  27035.0
# 589     FIAT       500X  2016  ...     25.0        819  20000.0
# 590     FIAT       500X  2016  ...     22.0        819  27335.0
# 591     FIAT       500X  2016  ...     21.0        819  25235.0
# 592     FIAT       500X  2017  ...     21.0        819  27035.0
# 593     FIAT       500X  2017  ...     22.0        819  25135.0
# 594     FIAT       500X  2017  ...     21.0        819  25235.0
# 595     FIAT       500X  2017  ...     21.0        819  23890.0
# 596     FIAT       500X  2017  ...     22.0        819  23335.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == '4dr SUV') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == '4dr SUV') & (car_price1.Vehicle_Size == 'Compact')].fillna('Crossover')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              59
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1498
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#              Make     Model  Year  ... city_mpg Popularity     MSRP
# 623         Mazda         5  2013  ...     22.0        586  24470.0
# 624         Mazda         5  2013  ...     22.0        586  20940.0
# 625         Mazda         5  2013  ...     21.0        586  19940.0
# 626         Mazda         5  2013  ...     22.0        586  22070.0
# 627         Mazda         5  2014  ...     21.0        586  20140.0
# ...           ...       ...   ...  ...      ...        ...      ...
# 11215  Mitsubishi  Vanwagon  1990  ...     18.0        436   2000.0
# 11252   Chevrolet   Venture  2003  ...     17.0       1385  21365.0
# 11253   Chevrolet   Venture  2003  ...     17.0       1385  22465.0
# 11255   Chevrolet   Venture  2003  ...     17.0       1385  25165.0
# 11262   Chevrolet   Venture  2004  ...     17.0       1385  21475.0
#
# [330 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Vehicle_Size == 'Compact')].head(60)
# Out:
#                Make           Model  Year  ... city_mpg Popularity     MSRP
# 623           Mazda               5  2013  ...     22.0        586  24470.0
# 624           Mazda               5  2013  ...     22.0        586  20940.0
# 625           Mazda               5  2013  ...     21.0        586  19940.0
# 626           Mazda               5  2013  ...     22.0        586  22070.0
# 627           Mazda               5  2014  ...     21.0        586  20140.0
# 628           Mazda               5  2014  ...     22.0        586  24670.0
# 629           Mazda               5  2014  ...     22.0        586  21140.0
# 630           Mazda               5  2014  ...     22.0        586  22270.0
# 631           Mazda               5  2015  ...     21.0        586  24770.0
# 632           Mazda               5  2015  ...     21.0        586  22370.0
# 633           Mazda               5  2015  ...     21.0        586  21240.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\826448936.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')

# %%
car_price1[(car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#              Make            Model  Year  ... city_mpg Popularity     MSRP
# 2337        Dodge          Caravan  2007  ...     17.0       1851  20555.0
# 2522    Chevrolet     City Express  2015  ...     24.0       1385  23515.0
# 2523    Chevrolet     City Express  2015  ...     24.0       1385  21955.0
# 2524    Chevrolet     City Express  2016  ...     24.0       1385  23515.0
# 2525    Chevrolet     City Express  2016  ...     24.0       1385  21955.0
# 2526    Chevrolet     City Express  2017  ...     24.0       1385  22405.0
# 2527    Chevrolet     City Express  2017  ...     24.0       1385  23515.0
# 6548    Chevrolet   Lumina Minivan  1994  ...     17.0       1385   2000.0
# 6550    Chevrolet   Lumina Minivan  1995  ...     17.0       1385   2000.0
# 6552    Chevrolet   Lumina Minivan  1996  ...     17.0       1385   2000.0
# 7264       Nissan            NV200  2015  ...     24.0       2009  21710.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\3552335815.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Vehicle_Size == 'Compact')].fillna('Flex Fuel')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              59
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1365
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Compact') & (car_price1.Market_Category.isnull())]
# Out:
#          Make    Model  Year  ... city_mpg Popularity     MSRP
# 2263      GMC   Canyon  2012  ...     18.0        549  24685.0
# 2266      GMC   Canyon  2012  ...     16.0        549  31790.0
# 2267      GMC   Canyon  2012  ...     16.0        549  28610.0
# 2271      GMC   Canyon  2012  ...     16.0        549  29125.0
# 2276      GMC   Canyon  2012  ...     17.0        549  26470.0
# ...       ...      ...   ...  ...      ...        ...      ...
# 10245  Toyota   Tacoma  2017  ...     19.0       2031  30190.0
# 11195     GMC  Vandura  1994  ...     15.0        549   2000.0
# 11198     GMC  Vandura  1994  ...     15.0        549   2000.0
# 11201     GMC  Vandura  1995  ...     15.0        549   2000.0
# 11203     GMC  Vandura  1995  ...     15.0        549   2000.0
#
# [197 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#          Make   Model  Year  ... city_mpg Popularity     MSRP
# 1777   Subaru    Baja  2004  ...     19.0        640  22795.0
# 1778   Subaru    Baja  2004  ...     16.0        640  23995.0
# 1779   Subaru    Baja  2004  ...     16.0        640  24995.0
# 1780   Subaru    Baja  2004  ...     19.0        640  21995.0
# 1781   Subaru    Baja  2004  ...     16.0        640  26295.0
# ...       ...     ...   ...  ...      ...        ...      ...
# 10240  Toyota  Tacoma  2017  ...     18.0       2031  33265.0
# 10241  Toyota  Tacoma  2017  ...     19.0       2031  31740.0
# 10242  Toyota  Tacoma  2017  ...     18.0       2031  38795.0
# 10244  Toyota  Tacoma  2017  ...     19.0       2031  32240.0
# 10245  Toyota  Tacoma  2017  ...     19.0       2031  30190.0
#
# [258 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].fillna('Crossover')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\3484349307.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Crew Cab Pickup') & (car_price1.Vehicle_Size == 'Compact')].fillna('Crossover')

# %%
car_price1[(car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#         Make      Model  Year  ... city_mpg Popularity     MSRP
# 8128   Dodge  Ram Cargo  2001  ...     13.0       1851  18695.0
# 8133   Dodge  Ram Cargo  2002  ...     13.0       1851  19275.0
# 8137   Dodge  Ram Cargo  2003  ...     13.0       1851  20035.0
# 8206   Dodge    Ram Van  1998  ...     13.0       1851   2000.0
# 8209   Dodge    Ram Van  1999  ...     14.0       1851   2041.0
# 8214   Dodge    Ram Van  2000  ...     13.0       1851   2087.0
# 11195    GMC    Vandura  1994  ...     15.0        549   2000.0
# 11198    GMC    Vandura  1994  ...     15.0        549   2000.0
# 11201    GMC    Vandura  1995  ...     15.0        549   2000.0
# 11203    GMC    Vandura  1995  ...     15.0        549   2000.0
#
# [10 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Vehicle_Size == 'Compact')].fillna('Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\3565748091.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Vehicle_Size == 'Compact')].fillna('Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              59
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1175
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[car_price1.Market_Category.isnull()]
# Out:
#          Make    Model  Year  ... city_mpg Popularity     MSRP
# 398     Mazda        3  2017  ...     28.0        586  21495.0
# 399     Mazda        3  2017  ...     27.0        586  17845.0
# 407     Mazda        3  2017  ...     28.0        586  18895.0
# 410     Mazda        3  2017  ...     27.0        586  20445.0
# 479    Toyota  4Runner  2014  ...     17.0       2031  41365.0
# ...       ...      ...   ...  ...      ...        ...      ...
# 11760  Nissan   Xterra  2015  ...     15.0       2009  25710.0
# 11761  Nissan   Xterra  2015  ...     15.0       2009  30590.0
# 11762  Nissan   Xterra  2015  ...     16.0       2009  23660.0
# 11763  Nissan   Xterra  2015  ...     15.0       2009  31640.0
# 11764  Nissan   Xterra  2015  ...     16.0       2009  25670.0
#
# [1175 rows x 16 columns]

# %%
car_price1[car_price1.Vehicle_Size == 'Midsize'].isna().sum()
# Out:
# Make                    0
# Model                   0
# Year                    0
# Engine_Fuel_Type        3
# Engine_HP              13
# Engine_Cylinders        0
# Transmission_Type       0
# Driven_Wheels           0
# Number_of_Doors         0
# Market_Category      1168
# Vehicle_Size            0
# Vehicle_Style           0
# highway_MPG             0
# city_mpg                0
# Popularity              0
# MSRP                    0
# dtype: int64

# %%
car_price1[car_price1.Vehicle_Size == 'Midsize'].Market_Category.unique()
# Out:
# array(['Luxury', 'Luxury,Performance', 'Flex Fuel',
#        'Flex Fuel,Performance', 'Hatchback,Luxury,Performance',
#        'Hatchback,Luxury', 'Luxury,High-Performance,Hybrid',
#        'Luxury,High-Performance', 'Diesel,Luxury', nan, 'Performance',
#        'Exotic,High-Performance', 'Exotic,Factory Tuner,High-Performance',
#        'Factory Tuner,Luxury,Performance', 'Flex Fuel,Luxury',
#        'Crossover,Luxury', 'Hatchback,Factory Tuner,Luxury,Performance',
#        'Crossover', 'Crossover,Hatchback', 'Hybrid',
#        'Crossover,Luxury,Performance,Hybrid',
#        'Crossover,Luxury,Performance',
#        'Factory Tuner,Luxury,High-Performance',
#        'Factory Tuner,High-Performance', 'High-Performance',
#        'Crossover,Flex Fuel', 'Crossover,Luxury,Diesel',
#        'Crossover,Luxury,High-Performance',
#        'Exotic,Flex Fuel,Factory Tuner,Luxury,High-Performance',
#        'Exotic,Factory Tuner,Luxury,High-Performance',
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan')].head(60)
# Out:
#          Make     Model  Year  ... city_mpg Popularity     MSRP
# 17       Audi       100  1992  ...     17.0       3105   2000.0
# 18       Audi       100  1992  ...     17.0       3105   2000.0
# 20       Audi       100  1992  ...     17.0       3105   2000.0
# 21       Audi       100  1992  ...     16.0       3105   2000.0
# 22       Audi       100  1993  ...     17.0       3105   2000.0
# 24       Audi       100  1993  ...     17.0       3105   2000.0
# 25       Audi       100  1993  ...     17.0       3105   2000.0
# 26       Audi       100  1993  ...     16.0       3105   2000.0
# 28       Audi       100  1994  ...     16.0       3105   2000.0
# 29       Audi       100  1994  ...     17.0       3105   2000.0
# 30       Audi       100  1994  ...     16.0       3105   2000.0
# 58       Audi       200  1990  ...     16.0       3105   2000.0
# 60       Audi       200  1990  ...     15.0       3105   2000.0
# 61       Audi       200  1991  ...     16.0       3105   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].head(60)
# Out:
#          Make   Model  Year  ... city_mpg Popularity     MSRP
# 398     Mazda       3  2017  ...     28.0        586  21495.0
# 399     Mazda       3  2017  ...     27.0        586  17845.0
# 407     Mazda       3  2017  ...     28.0        586  18895.0
# 410     Mazda       3  2017  ...     27.0        586  20445.0
# 674   Pontiac    6000  1990  ...     17.0        210   2000.0
# 675   Pontiac    6000  1990  ...     20.0        210   2000.0
# 678   Pontiac    6000  1990  ...     17.0        210   2000.0
# 680   Pontiac    6000  1991  ...     17.0        210   2000.0
# 681   Pontiac    6000  1991  ...     19.0        210   2000.0
# 685     Mazda     626  2000  ...     19.0        586   2080.0
# 686     Mazda     626  2000  ...     19.0        586   2234.0
# 687     Mazda     626  2000  ...     23.0        586   2000.0
# 688     Mazda     626  2000  ...     19.0        586   2146.0
# 689     Mazda     626  2001  ...     19.0        586  22935.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].Market_Category = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].Market_Category.fillna('Luxury, Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\2297990645.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].Market_Category = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].Market_Category.fillna('Luxury, Performance')

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())]
# Out:
#          Make    Model  Year  ... city_mpg Popularity     MSRP
# 398     Mazda        3  2017  ...     28.0        586  21495.0
# 399     Mazda        3  2017  ...     27.0        586  17845.0
# 407     Mazda        3  2017  ...     28.0        586  18895.0
# 410     Mazda        3  2017  ...     27.0        586  20445.0
# 479    Toyota  4Runner  2014  ...     17.0       2031  41365.0
# ...       ...      ...   ...  ...      ...        ...      ...
# 11760  Nissan   Xterra  2015  ...     15.0       2009  25710.0
# 11761  Nissan   Xterra  2015  ...     15.0       2009  30590.0
# 11762  Nissan   Xterra  2015  ...     16.0       2009  23660.0
# 11763  Nissan   Xterra  2015  ...     15.0       2009  31640.0
# 11764  Nissan   Xterra  2015  ...     16.0       2009  25670.0
#
# [1168 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].fillna('Luxury, Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\2815231064.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Sedan') & (car_price1.Market_Category.isnull())].fillna('Luxury, Performance')

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())]
# Out:
#          Make    Model  Year  ... city_mpg Popularity     MSRP
# 479    Toyota  4Runner  2014  ...     17.0       2031  41365.0
# 480    Toyota  4Runner  2014  ...     17.0       2031  35740.0
# 481    Toyota  4Runner  2014  ...     17.0       2031  37615.0
# 482    Toyota  4Runner  2014  ...     17.0       2031  34695.0
# 483    Toyota  4Runner  2014  ...     17.0       2031  35725.0
# ...       ...      ...   ...  ...      ...        ...      ...
# 11760  Nissan   Xterra  2015  ...     15.0       2009  25710.0
# 11761  Nissan   Xterra  2015  ...     15.0       2009  30590.0
# 11762  Nissan   Xterra  2015  ...     16.0       2009  23660.0
# 11763  Nissan   Xterra  2015  ...     15.0       2009  31640.0
# 11764  Nissan   Xterra  2015  ...     16.0       2009  25670.0
#
# [618 rows x 16 columns]

# %%
car_price1.isna().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP             59
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      625
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].Vehicle_Style.unique()
# Out:
# array(['4dr SUV', 'Wagon', 'Coupe', 'Cargo Minivan', 'Passenger Minivan',
#        '2dr SUV', 'Convertible', 'Cargo Van', 'Passenger Van'],
#       dtype=object)

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == '4dr SUV')]
# Out:
#          Make    Model  Year  ... city_mpg Popularity     MSRP
# 479    Toyota  4Runner  2014  ...     17.0       2031  41365.0
# 480    Toyota  4Runner  2014  ...     17.0       2031  35740.0
# 481    Toyota  4Runner  2014  ...     17.0       2031  37615.0
# 482    Toyota  4Runner  2014  ...     17.0       2031  34695.0
# 483    Toyota  4Runner  2014  ...     17.0       2031  35725.0
# ...       ...      ...   ...  ...      ...        ...      ...
# 11760  Nissan   Xterra  2015  ...     15.0       2009  25710.0
# 11761  Nissan   Xterra  2015  ...     15.0       2009  30590.0
# 11762  Nissan   Xterra  2015  ...     16.0       2009  23660.0
# 11763  Nissan   Xterra  2015  ...     15.0       2009  31640.0
# 11764  Nissan   Xterra  2015  ...     16.0       2009  25670.0
#
# [234 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == '4dr SUV')].head(60)
# Out:
#         Make           Model  Year  ... city_mpg Popularity     MSRP
# 479   Toyota         4Runner  2014  ...     17.0       2031  41365.0
# 480   Toyota         4Runner  2014  ...     17.0       2031  35740.0
# 481   Toyota         4Runner  2014  ...     17.0       2031  37615.0
# 482   Toyota         4Runner  2014  ...     17.0       2031  34695.0
# 483   Toyota         4Runner  2014  ...     17.0       2031  35725.0
# 484   Toyota         4Runner  2014  ...     17.0       2031  43400.0
# 485   Toyota         4Runner  2014  ...     17.0       2031  32820.0
# 486   Toyota         4Runner  2014  ...     17.0       2031  38645.0
# 487   Toyota         4Runner  2015  ...     17.0       2031  37825.0
# 488   Toyota         4Runner  2015  ...     17.0       2031  43620.0
# 489   Toyota         4Runner  2015  ...     17.0       2031  36115.0
# 490   Toyota         4Runner  2015  ...     17.0       2031  35950.0
# 491   Toyota         4Runner  2015  ...     17.0       2031  33210.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == '4dr SUV')] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == '4dr SUV')].fillna('Crossover')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\385867853.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == '4dr SUV')] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == '4dr SUV')].fillna('Crossover')

# %%
car_price1.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP             59
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      391
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].Vehicle_Style.unique()
# Out:
# array(['Wagon', 'Coupe', 'Cargo Minivan', 'Passenger Minivan', '2dr SUV',
#        'Convertible', 'Cargo Van', 'Passenger Van'], dtype=object)

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Wagon')]
# Out:
#             Make          Model  Year  ... city_mpg Popularity    MSRP
# 676      Pontiac           6000  1990  ...     17.0        210  2000.0
# 677      Pontiac           6000  1990  ...     17.0        210  2000.0
# 679      Pontiac           6000  1991  ...     17.0        210  2000.0
# 2425   Chevrolet      Celebrity  1990  ...     17.0       1385  2000.0
# 2426   Chevrolet      Celebrity  1990  ...     20.0       1385  2000.0
# 2516  Oldsmobile          Ciera  1995  ...     17.0         26  2000.0
# 2518  Oldsmobile          Ciera  1996  ...     18.0         26  2000.0
# 3315  Oldsmobile  Cutlass Ciera  1992  ...     17.0         26  2000.0
# 3316  Oldsmobile  Cutlass Ciera  1992  ...     19.0         26  2000.0
# 3319  Oldsmobile  Cutlass Ciera  1993  ...     18.0         26  2000.0
# 3320  Oldsmobile  Cutlass Ciera  1993  ...     18.0         26  2000.0
# 3324  Oldsmobile  Cutlass Ciera  1994  ...     17.0         26  2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Wagon')].head(60)
# Out:
#                Make      Model  Year  ... city_mpg Popularity     MSRP
# 19             Audi        100  1992  ...     16.0       3105   2000.0
# 23             Audi        100  1993  ...     16.0       3105   2000.0
# 27             Audi        100  1994  ...     16.0       3105   2000.0
# 31             Audi        100  1994  ...     16.0       3105   2000.0
# 59             Audi        200  1990  ...     15.0       3105   2000.0
# 62             Audi        200  1991  ...     16.0       3105   2000.0
# 104           Volvo        240  1991  ...     19.0        870   2000.0
# 105           Volvo        240  1991  ...     18.0        870   2000.0
# 108           Volvo        240  1992  ...     19.0        870   2000.0
# 111           Volvo        240  1993  ...     18.0        870   2000.0
# 131             BMW   3 Series  2015  ...     22.0       3916  41950.0
# 140             BMW   3 Series  2015  ...     31.0       3916  43450.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())].fillna('Luxury, Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\306864328.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Wagon') & (car_price1.Market_Category.isnull())].fillna('Luxury, Performance')

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].Vehicle_Style.unique()
# Out:
# array(['Coupe', 'Cargo Minivan', 'Passenger Minivan', '2dr SUV',
#        'Convertible', 'Cargo Van', 'Passenger Van'], dtype=object)

# %%
car_price1.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP             59
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      378
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Coupe')].head(60)
# Out:
#                Make      Model  Year  ... city_mpg Popularity      MSRP
# 173   Mercedes-Benz  300-Class  1991  ...     15.0        617    2179.0
# 180   Mercedes-Benz  300-Class  1992  ...     15.0        617    2248.0
# 186   Mercedes-Benz  300-Class  1993  ...     17.0        617    2397.0
# 426             BMW   4 Series  2015  ...     21.0       3916   46250.0
# 428             BMW   4 Series  2015  ...     22.0       3916   42750.0
# 430             BMW   4 Series  2015  ...     20.0       3916   48250.0
# 431             BMW   4 Series  2015  ...     22.0       3916   42750.0
# 433             BMW   4 Series  2015  ...     23.0       3916   40750.0
# 436             BMW   4 Series  2015  ...     23.0       3916   40750.0
# 439             BMW   4 Series  2016  ...     22.0       3916   41850.0
# 440             BMW   4 Series  2016  ...     20.0       3916   50150.0
# 441             BMW   4 Series  2016  ...     23.0       3916   41850.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Coupe')] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Coupe')].fillna('Luxury, Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\354706998.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Coupe')] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Style == 'Coupe')].fillna('Luxury, Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP             59
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      293
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].Vehicle_Style.unique()
# Out:
# array(['Cargo Minivan', 'Passenger Minivan', '2dr SUV', 'Convertible',
#        'Cargo Van', 'Passenger Van'], dtype=object)

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Cargo Minivan')].head(60)
# Out:
#             Make           Model  Year  ... city_mpg Popularity     MSRP
# 1331        Ford        Aerostar  1995  ...     16.0       5657   2000.0
# 1338        Ford        Aerostar  1996  ...     16.0       5657   2000.0
# 1339        Ford        Aerostar  1997  ...     15.0       5657   2000.0
# 4916        Ford        Freestar  2005  ...     16.0       5657  21630.0
# 4920        Ford        Freestar  2006  ...     16.0       5657  19650.0
# 4927        Ford        Freestar  2007  ...     15.0       5657  19700.0
# 11075  Chevrolet        Uplander  2006  ...     16.0       1385  21150.0
# 11079  Chevrolet        Uplander  2007  ...     16.0       1385  22105.0
# 11089  Chevrolet        Uplander  2008  ...     16.0       1385  23080.0
# 11250  Chevrolet         Venture  2003  ...     17.0       1385  22440.0
# 11261  Chevrolet         Venture  2004  ...     17.0       1385  22600.0
# 11265  Chevrolet         Venture  2005  ...     17.0       1385  23165.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Market_Category.isnull())]
# Out:
#             Make           Model  Year  ... city_mpg Popularity     MSRP
# 1331        Ford        Aerostar  1995  ...     16.0       5657   2000.0
# 1338        Ford        Aerostar  1996  ...     16.0       5657   2000.0
# 1339        Ford        Aerostar  1997  ...     15.0       5657   2000.0
# 4916        Ford        Freestar  2005  ...     16.0       5657  21630.0
# 4920        Ford        Freestar  2006  ...     16.0       5657  19650.0
# 4927        Ford        Freestar  2007  ...     15.0       5657  19700.0
# 11075  Chevrolet        Uplander  2006  ...     16.0       1385  21150.0
# 11250  Chevrolet         Venture  2003  ...     17.0       1385  22440.0
# 11261  Chevrolet         Venture  2004  ...     17.0       1385  22600.0
# 11265  Chevrolet         Venture  2005  ...     17.0       1385  23165.0
# 11427       Ford  Windstar Cargo  2001  ...     16.0       5657  20220.0
# 11428       Ford  Windstar Cargo  2002  ...     16.0       5657  20585.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Cargo Minivan') & (car_price1.Market_Category.isnull())].fillna('Flex Fuel')

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Passenger Minivan')].head(60)
# Out:
#             Make          Model  Year  ... city_mpg Popularity     MSRP
# 1332        Ford       Aerostar  1995  ...     15.0       5657   2000.0
# 1335        Ford       Aerostar  1996  ...     15.0       5657   2000.0
# 1342        Ford       Aerostar  1997  ...     15.0       5657   2000.0
# 3973     Hyundai      Entourage  2007  ...     16.0       1439  26395.0
# 3974     Hyundai      Entourage  2007  ...     16.0       1439  28895.0
# 3975     Hyundai      Entourage  2007  ...     16.0       1439  23895.0
# 3976     Hyundai      Entourage  2008  ...     16.0       1439  29895.0
# 3977     Hyundai      Entourage  2008  ...     16.0       1439  23995.0
# 4914        Ford       Freestar  2005  ...     16.0       5657  28030.0
# 4915        Ford       Freestar  2005  ...     16.0       5657  23930.0
# 4917        Ford       Freestar  2005  ...     16.0       5657  26530.0
# 4918        Ford       Freestar  2005  ...     16.0       5657  29030.0
# ...

# %%
car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Size == 'Midsize') & (car_price1.Vehicle_Style == 'Passenger Minivan') & (car_price1.Market_Category.isnull())].fillna('Performance, Flex Fuel')

# %%
car_price1.isnull().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP             53
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      130
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
car_price1[car_price1.Engine_HP.isnull()]
# Out:
#                Make        Model  Year  ... city_mpg Popularity      MSRP
# 539            FIAT         500e  2015  ...    122.0        819   31800.0
# 540            FIAT         500e  2016  ...    121.0        819   31800.0
# 541            FIAT         500e  2017  ...    121.0        819   31800.0
# 2905        Lincoln  Continental  2017  ...     17.0         61   55915.0
# 2906        Lincoln  Continental  2017  ...     18.0         61   62915.0
# 2907        Lincoln  Continental  2017  ...     18.0         61   53915.0
# 2908        Lincoln  Continental  2017  ...     17.0         61   64915.0
# 4705          Honda       Fit EV  2013  ...    132.0       2202   36625.0
# 4706          Honda       Fit EV  2014  ...    132.0       2202   36625.0
# 4785           Ford        Focus  2015  ...    110.0       5657   29170.0
# 4789           Ford        Focus  2016  ...    110.0       5657   29170.0
# 4798           Ford        Focus  2017  ...    110.0       5657   29120.0
# ...

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'electric') & car_price1.Engine_HP.isnull()].Engine_HP = car_price1[(car_price1.Engine_Fuel_Type == 'electric') & car_price1.Engine_HP.isnull()].Engine_HP.fillna(car_price1.Engine_HP.mode())
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\876061359.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Engine_Fuel_Type == 'electric') & car_price1.Engine_HP.isnull()].Engine_HP = car_price1[(car_price1.Engine_Fuel_Type == 'electric') & car_price1.Engine_HP.isnull()].Engine_HP.fillna(car_price1.Engine_HP.mode())
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\876061359.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
car_price1.Engine_HP = car_price1.Engine_HP.replace('Luxury, Performance', 170)

# %%
car_price1.Engine_HP.isnull().sum()
# Out:
# np.int64(53)

# %%
car_price1.Engine_HP.mode()
# Out:
# 0    200.0
# Name: Engine_HP, dtype: object

# %%
car_price1[(car_price1.Engine_HP.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')] = car_price1[(car_price1.Engine_HP.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')].fillna(car_price1[(car_price1.Engine_Fuel_Type == 'electric')].Engine_HP.head(60).mean().round(1))
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\3525648697.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Engine_HP.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')] = car_price1[(car_price1.Engine_HP.isnull()) & (car_price1.Engine_Fuel_Type == 'electric')].fillna(car_price1[(car_price1.Engine_Fuel_Type == 'electric')].Engine_HP.head(60).mean().round(1))

# %%
car_price1[(car_price1.Engine_Fuel_Type == 'electric')].Engine_HP.head(60).mean().round(1)
# Out:
# np.float64(145.8)

# %%
car_price1.Engine_HP.isnull().sum()
# Out:
# np.int64(15)

# %%
car_price1[car_price1.Engine_HP.isnull()]
# Out:
#                Make        Model  Year  ... city_mpg Popularity     MSRP
# 2905        Lincoln  Continental  2017  ...     17.0         61  55915.0
# 2906        Lincoln  Continental  2017  ...     18.0         61  62915.0
# 2907        Lincoln  Continental  2017  ...     18.0         61  53915.0
# 2908        Lincoln  Continental  2017  ...     17.0         61  64915.0
# 5825      Chevrolet       Impala  2015  ...     17.0       1385  40660.0
# 5830      Chevrolet       Impala  2015  ...     17.0       1385  37535.0
# 5831      Chevrolet       Impala  2016  ...     17.0       1385  40810.0
# 5833      Chevrolet       Impala  2016  ...     17.0       1385  37570.0
# 5839      Chevrolet       Impala  2017  ...     17.0       1385  37675.0
# 5840      Chevrolet       Impala  2017  ...     17.0       1385  40915.0
# 6578  Mercedes-Benz      M-Class  2015  ...     22.0        617  49800.0
# 6908        Lincoln          MKZ  2017  ...     41.0         61  35010.0
# ...

# %%
car_price1[(car_price1.Engine_Cylinders == 4.0)].Engine_HP.head(1000).mean().round(1)
# Out:
# np.float64(183.3)

# %%
car_price1.Engine_HP = car_price1.Engine_HP.ffill()

# %%
car_price1[car_price1.Engine_HP.isnull()]
# Out:
# Empty DataFrame
# Columns: [Make, Model, Year, Engine_Fuel_Type, Engine_HP, Engine_Cylinders, Transmission_Type, Driven_Wheels, Number_of_Doors, Market_Category, Vehicle_Size, Vehicle_Style, highway_MPG, city_mpg, Popularity, MSRP]
# Index: []

# %%
car_price1.Engine_HP.unique()
# Out:
# array([335.0, 300.0, 230.0, 320.0, 172.0, 160.0, 130.0, 158.0, 240.0,
#        248.0, 162.0, 217.0, 184.0, 295.0, 115.0, 140.0, 155.0, 114.0,
#        100.0, 241.0, 180.0, 177.0, 228.0, 121.0, 148.0, 194.0, 218.0,
#        161.0, 292.0, 250.0, 255.0, 222.0, 82.0, 134.0, 306.0, 400.0,
#        425.0, 350.0, 332.0, 268.0, 282.0, 275.0, 201.0, 442.0, 562.0,
#        597.0, 237.0, 270.0, 445.0, 443.0, 302.0, 322.0, 315.0, 145.8,
#        101.0, 135.0, 485.0, 238.0, 515.0, 543.0, 631.0, 604.0, 620.0,
#        611.0, 661.0, 157.0, 402.0, 389.0, 110.0, 532.0, 170.0, 165.0,
#        125.0, 641.0, 535.0, 153.0, 144.0, 188.0, 372.0, 108.0, 168.0,
#        190.0, 205.0, 200.0, 227.0, 173.0, 220.0, 210.0, 280.0, 207.0,
#        265.0, 260.0, 290.0, 285.0, 390.0, 225.0, 185.0, 150.0, 430.0,
#        520.0, 560.0, 475.0, 500.0, 540.0, 370.0, 580.0, 420.0, 345.0,
#        195.0, 193.0, 208.0, 181.0, 236.0, 186.0, 252.0, 310.0, 333.0,
# ...

# %%
car_price1.isna().sum()
# Out:
# Make                   0
# Model                  0
# Year                   0
# Engine_Fuel_Type       0
# Engine_HP              0
# Engine_Cylinders       0
# Transmission_Type      0
# Driven_Wheels          0
# Number_of_Doors        0
# Market_Category      130
# Vehicle_Size           0
# Vehicle_Style          0
# highway_MPG            0
# city_mpg               0
# Popularity             0
# MSRP                   0
# dtype: int64

# %%
car_price1[car_price1.Market_Category.isnull()].head(60)
# Out:
#             Make            Model  Year  ... city_mpg Popularity     MSRP
# 2031        Ford           Bronco  1994  ...     12.0       5657   2308.0
# 2032        Ford           Bronco  1994  ...     12.0       5657   2585.0
# 2033        Ford           Bronco  1994  ...     12.0       5657   2396.0
# 2034        Ford           Bronco  1995  ...     12.0       5657   2620.0
# 2035        Ford           Bronco  1995  ...     12.0       5657   2872.0
# 2036        Ford           Bronco  1995  ...     12.0       5657   2474.0
# 2037        Ford           Bronco  1996  ...     13.0       5657   2774.0
# 2038        Ford           Bronco  1996  ...     13.0       5657   2996.0
# 2039        Ford           Bronco  1996  ...     11.0       5657   3248.0
# 2213      Toyota     Camry Solara  2006  ...     18.0       2031  26940.0
# 2215      Toyota     Camry Solara  2006  ...     18.0       2031  30210.0
# 2223      Toyota     Camry Solara  2007  ...     18.0       2031  29460.0
# ...

# %%
car_price1[car_price1.Market_Category.isnull()].Vehicle_Style.unique()
# Out:
# array(['2dr SUV', 'Convertible', 'Cargo Van', 'Passenger Van'],
#       dtype=object)

# %%
car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Midsize')]
# Out:
#        Make           Model  Year  ... city_mpg Popularity     MSRP
# 2031   Ford          Bronco  1994  ...     12.0       5657   2308.0
# 2032   Ford          Bronco  1994  ...     12.0       5657   2585.0
# 2033   Ford          Bronco  1994  ...     12.0       5657   2396.0
# 2034   Ford          Bronco  1995  ...     12.0       5657   2620.0
# 2035   Ford          Bronco  1995  ...     12.0       5657   2872.0
# 2036   Ford          Bronco  1995  ...     12.0       5657   2474.0
# 2037   Ford          Bronco  1996  ...     13.0       5657   2774.0
# 2038   Ford          Bronco  1996  ...     13.0       5657   2996.0
# 2039   Ford          Bronco  1996  ...     11.0       5657   3248.0
# 4373   Ford  Explorer Sport  2001  ...     14.0       5657  24055.0
# 4374   Ford  Explorer Sport  2001  ...     16.0       5657  21035.0
# 4375   Ford  Explorer Sport  2002  ...     15.0       5657  24615.0
# 4376   Ford  Explorer Sport  2002  ...     14.0       5657  24240.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Midsize')] = car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Midsize')].fillna('Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\2350806765.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Midsize')] = car_price1[(car_price1.Vehicle_Style == '2dr SUV') & (car_price1.Vehicle_Size == 'Midsize')].fillna('Performance')

# %%
car_price1[car_price1.Market_Category.isnull()].Vehicle_Style.unique()
# Out:
# array(['Convertible', 'Cargo Van', 'Passenger Van'], dtype=object)

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible') & (car_price1.Vehicle_Size == 'Midsize')]
# Out:
#                Make     Model  Year  ... city_mpg Popularity      MSRP
# 425             BMW  4 Series  2015  ...     20.0       3916   56900.0
# 427             BMW  4 Series  2015  ...     21.0       3916   50750.0
# 429             BMW  4 Series  2015  ...     23.0       3916   48750.0
# 432             BMW  4 Series  2015  ...     21.0       3916   50750.0
# 434             BMW  4 Series  2015  ...     20.0       3916   54900.0
# ...             ...       ...   ...  ...      ...        ...       ...
# 11206  Aston Martin  Vanquish  2014  ...     13.0        259  296295.0
# 11208  Aston Martin  Vanquish  2015  ...     13.0        259  301695.0
# 11211  Aston Martin  Vanquish  2016  ...     13.0        259  305650.0
# 11213  Aston Martin  Vanquish  2016  ...     13.0        259  320695.0
# 11395  Aston Martin    Virage  2012  ...     13.0        259  223295.0
#
# [192 rows x 16 columns]

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())]
# Out:
#             Make            Model  Year  ... city_mpg Popularity     MSRP
# 2213      Toyota     Camry Solara  2006  ...     18.0       2031  26940.0
# 2215      Toyota     Camry Solara  2006  ...     18.0       2031  30210.0
# 2223      Toyota     Camry Solara  2007  ...     18.0       2031  29460.0
# 2224      Toyota     Camry Solara  2007  ...     18.0       2031  27190.0
# 2230      Toyota     Camry Solara  2007  ...     18.0       2031  30460.0
# 2233      Toyota     Camry Solara  2008  ...     18.0       2031  27440.0
# 2238      Toyota     Camry Solara  2008  ...     18.0       2031  30710.0
# 2242      Toyota     Camry Solara  2008  ...     18.0       2031  29710.0
# 2341       Buick          Cascada  2016  ...     20.0        155  33065.0
# 2342       Buick          Cascada  2016  ...     20.0        155  36065.0
# 2343       Buick          Cascada  2017  ...     20.0        155  36065.0
# 2344       Buick          Cascada  2017  ...     20.0        155  33065.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Convertible') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == 'Convertible') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].fillna('Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1997172090.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Convertible') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == 'Convertible') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].fillna('Performance')

# %%
car_price1[car_price1.Market_Category.isnull()].Vehicle_Style.unique()
# Out:
# array(['Cargo Van', 'Passenger Van'], dtype=object)

# %%
car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())]
# Out:
#            Make        Model  Year  ... city_mpg Popularity     MSRP
# 3644       Ford        E-150  1996  ...     11.0       5657   2000.0
# 3646       Ford        E-150  1996  ...     11.0       5657   2000.0
# 3647       Ford        E-150  1996  ...     11.0       5657   2000.0
# 3649       Ford        E-150  1997  ...     12.0       5657   2000.0
# 3650       Ford        E-150  1997  ...     12.0       5657   2123.0
# 3651       Ford        E-150  1997  ...     12.0       5657   2074.0
# 3653       Ford        E-150  1998  ...     12.0       5657   2301.0
# 3655       Ford        E-150  1998  ...     12.0       5657   2256.0
# 3656       Ford        E-150  1998  ...     12.0       5657   2169.0
# 8038        GMC  Rally Wagon  1994  ...     11.0        549   2000.0
# 8216      Dodge    Ram Wagon  2000  ...     11.0       1851   2332.0
# 8217      Dodge    Ram Wagon  2001  ...     11.0       1851  23360.0
# 9936  Chevrolet     Sportvan  1994  ...     11.0       1385   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].fillna('Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1019069415.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].fillna('Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine_Fuel_Type      0
# Engine_HP             0
# Engine_Cylinders      0
# Transmission_Type     0
# Driven_Wheels         0
# Number_of_Doors       0
# Market_Category      39
# Vehicle_Size          0
# Vehicle_Style         0
# highway_MPG           0
# city_mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
car_price1[(car_price1.Vehicle_Style == 'Cargo Van') & (car_price1.Vehicle_Size == 'Midsize') ]
# Out:
#             Make          Model  Year  ... city_mpg Popularity     MSRP
# 2507   Chevrolet      Chevy Van  1996  ...     14.0       1385   2000.0
# 2508   Chevrolet      Chevy Van  1996  ...     14.0       1385   2000.0
# 2511   Chevrolet      Chevy Van  1997  ...     14.0       1385   2000.0
# 2512   Chevrolet      Chevy Van  1997  ...     14.0       1385   2000.0
# 2513   Chevrolet      Chevy Van  1998  ...     13.0       1385   2050.0
# 2514   Chevrolet      Chevy Van  1998  ...     13.0       1385   2052.0
# 3645        Ford          E-150  1996  ...     12.0       5657   2000.0
# 3648        Ford          E-150  1996  ...     12.0       5657   2000.0
# 3652        Ford          E-150  1997  ...     14.0       5657   2000.0
# 3654        Ford          E-150  1998  ...     13.0       5657   2079.0
# 3658        Ford          E-250  1996  ...     11.0       5657   2000.0
# 3660        Ford          E-250  1996  ...     11.0       5657   2000.0
# ...

# %%
car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())] = car_price1[(car_price1.Vehicle_Style == 'Passenger Van') & (car_price1.Vehicle_Size == 'Midsize') & (car_price1.Market_Category.isnull())].fillna('Performance')

# %%
car_price1.isna().sum()
# Out:
# Make                  0
# Model                 0
# Year                  0
# Engine_Fuel_Type      0
# Engine_HP             0
# Engine_Cylinders      0
# Transmission_Type     0
# Driven_Wheels         0
# Number_of_Doors       0
# Market_Category      39
# Vehicle_Size          0
# Vehicle_Style         0
# highway_MPG           0
# city_mpg              0
# Popularity            0
# MSRP                  0
# dtype: int64

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Midsize')]
# Out:
#             Make      Model  Year  ... city_mpg Popularity     MSRP
# 2507   Chevrolet  Chevy Van  1996  ...     14.0       1385   2000.0
# 2508   Chevrolet  Chevy Van  1996  ...     14.0       1385   2000.0
# 2511   Chevrolet  Chevy Van  1997  ...     14.0       1385   2000.0
# 2512   Chevrolet  Chevy Van  1997  ...     14.0       1385   2000.0
# 2513   Chevrolet  Chevy Van  1998  ...     13.0       1385   2050.0
# 2514   Chevrolet  Chevy Van  1998  ...     13.0       1385   2052.0
# 3645        Ford      E-150  1996  ...     12.0       5657   2000.0
# 3648        Ford      E-150  1996  ...     12.0       5657   2000.0
# 3652        Ford      E-150  1997  ...     14.0       5657   2000.0
# 3654        Ford      E-150  1998  ...     13.0       5657   2079.0
# 3658        Ford      E-250  1996  ...     11.0       5657   2000.0
# 3660        Ford      E-250  1996  ...     11.0       5657   2000.0
# 3663        Ford      E-250  1997  ...     12.0       5657   2000.0
# ...

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Midsize')] = car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Midsize')].fillna('Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1461048414.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Midsize')] = car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Midsize')].fillna('Performance')

# %%
car_price1.isna().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine_Fuel_Type     0
# Engine_HP            0
# Engine_Cylinders     0
# Transmission_Type    0
# Driven_Wheels        0
# Number_of_Doors      0
# Market_Category      7
# Vehicle_Size         0
# Vehicle_Style        0
# highway_MPG          0
# city_mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')]
# Out:
#        Make        Model  Year  ... city_mpg Popularity     MSRP
# 8037    GMC  Rally Wagon  1994  ...     14.0        549   2000.0
# 8039    GMC  Rally Wagon  1994  ...     14.0        549   2000.0
# 8040    GMC  Rally Wagon  1995  ...     13.0        549   2000.0
# 8041    GMC  Rally Wagon  1995  ...     13.0        549   2000.0
# 8215  Dodge    Ram Wagon  2000  ...     13.0       1851   2326.0
# 8218  Dodge    Ram Wagon  2001  ...     12.0       1851  21345.0
# 8219  Dodge    Ram Wagon  2002  ...     13.0       1851  21345.0
#
# [7 rows x 16 columns]

# %%
car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')].fillna('Performance')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\3852016075.py:1: FutureWarning: Downcasting object dtype arrays on .fillna, .ffill, .bfill is deprecated and will change in a future version. Call result.infer_objects(copy=False) instead. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')] = car_price1[(car_price1.Market_Category.isnull()) & (car_price1.Vehicle_Size == 'Compact')].fillna('Performance')

# %%
car_price1.isnull().sum()
# Out:
# Make                 0
# Model                0
# Year                 0
# Engine_Fuel_Type     0
# Engine_HP            0
# Engine_Cylinders     0
# Transmission_Type    0
# Driven_Wheels        0
# Number_of_Doors      0
# Market_Category      0
# Vehicle_Size         0
# Vehicle_Style        0
# highway_MPG          0
# city_mpg             0
# Popularity           0
# MSRP                 0
# dtype: int64

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11914 non-null  object
#  4   Engine_HP          11914 non-null  object
#  5   Engine_Cylinders   11914 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11914 non-null  int64
#  9   Market_Category    11914 non-null  object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %%
for i in car_price1.Engine_HP.unique():
    print(i)
# Out:
# 335.0
# 300.0
# 230.0
# 320.0
# 172.0
# 160.0
# 130.0
# 158.0
# 240.0
# 248.0
# 162.0
# 217.0
# 184.0
# 295.0
# 115.0
# 140.0
# 155.0
# 114.0
# 100.0
# 241.0
# 180.0
# 177.0
# 228.0
# 121.0
# 148.0
# 194.0
# 218.0
# 161.0
# 292.0
# 250.0
# 255.0
# 222.0
# 82.0
# 134.0
# 306.0
# 400.0
# 425.0
# 350.0
# 332.0
# 268.0
# 282.0
# 275.0
# 201.0
# 442.0
# 562.0
# 597.0
# 237.0
# 270.0
# 445.0
# 443.0
# 302.0
# 322.0
# 315.0
# 145.8
# 101.0
# 135.0
# 485.0
# 238.0
# 515.0
# 543.0
# 631.0
# 604.0
# 620.0
# 611.0
# 661.0
# 157.0
# 402.0
# 389.0
# 110.0
# 532.0
# 170.0
# 165.0
# 125.0
# 641.0
# 535.0
# 153.0
# 144.0
# 188.0
# 372.0
# 108.0
# 168.0
# 190.0
# 205.0
# 200.0
# 227.0
# 173.0
# 220.0
# 210.0
# 280.0
# 207.0
# 265.0
# 260.0
# 290.0
# 285.0
# 390.0
# 225.0
# 185.0
# 150.0
# 430.0
# 520.0
# 560.0
# 475.0
# 500.0
# 540.0
# 370.0
# 580.0
# 420.0
# 345.0
# 195.0
# 193.0
# 208.0
# 181.0
# 236.0
# 186.0
# 252.0
# 310.0
# 333.0
# 340.0
# 450.0
# 281.0
# 288.0
# 138.0
# 137.0
# 106.0
# 271.0
# ...

# %%
car_price1.Engine_HP.replace('Crossover', 1012.394, inplace = True)
car_price1.Engine_HP.replace('Performance, Flex Fuel',  1012.394, inplace = True)
car_price1.Engine_HP.replace('Flex Fuel',  1012.394, inplace = True)
car_price1.Engine_HP.astype('float64')
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1968950469.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   car_price1.Engine_HP.replace('Crossover', 1012.394, inplace = True)
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_7504\1968950469.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
car_price1.Engine_HP.replace( 1012.394, car_price1.Engine_HP.mean(), inplace = True)
car_price1.Engine_HP.replace(  1012.394, car_price1.Engine_HP.mean(), inplace = True)
car_price1.Engine_HP.replace( 1012.394, car_price1.Engine_HP.mean(), inplace = True)
car_price1.Engine_HP.astype('float64')
# Out:
# 0        335.0
# 1        300.0
# 2        300.0
# 3        230.0
# 4        230.0
#          ...
# 11909    300.0
# 11910    300.0
# 11911    300.0
# 11912    300.0
# 11913    221.0
# Name: Engine_HP, Length: 11914, dtype: float64

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11914 non-null  object
#  4   Engine_HP          11914 non-null  float64
#  5   Engine_Cylinders   11914 non-null  float64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11914 non-null  int64
#  9   Market_Category    11914 non-null  object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %%
car_price1.Engine_Cylinders = car_price1.Engine_Cylinders.astype('int64')

# %%
car_price1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11914 non-null  object
#  4   Engine_HP          11914 non-null  float64
#  5   Engine_Cylinders   11914 non-null  int64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11914 non-null  int64
#  9   Market_Category    11914 non-null  object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %% [markdown]
# # Describing the data

# %%
car_price1.describe().round()
# Out:
#           Year  Engine_HP  Engine_Cylinders  ...  city_mpg  Popularity       MSRP
# count  11914.0    11914.0           11914.0  ...   11914.0     11914.0    11914.0
# mean    2010.0      249.0               6.0  ...      20.0      1555.0    40595.0
# std        8.0      109.0               2.0  ...       9.0      1442.0    60109.0
# min     1990.0        0.0               0.0  ...       7.0         2.0     2000.0
# 25%     2007.0      170.0               4.0  ...      16.0       549.0    21000.0
# 50%     2015.0      226.0               6.0  ...      18.0      1385.0    29995.0
# 75%     2016.0      300.0               6.0  ...      22.0      2009.0    42231.0
# max     2017.0     1001.0              16.0  ...     137.0      5657.0  2065902.0
#
# [8 rows x 8 columns]

# %% [markdown]
# # what are the top 10 makes

# %%
top_10_makes = car_price1['Make'].value_counts().head(10)
top_10_makes
# Out:
# Make
# Chevrolet     1123
# Ford           881
# Volkswagen     809
# Toyota         746
# Dodge          626
# Nissan         558
# GMC            515
# Honda          449
# Mazda          423
# Cadillac       397
# Name: count, dtype: int64

# %% [markdown]
# # what are the top 10 most expensive makes

# %%
top_10_expensive_makes = car_price1.groupby('Make')['MSRP'].mean().sort_values(ascending=False).round().head(10)
top_10_expensive_makes
# Out:
# Make
# Bugatti         1757224.0
# Maybach          546222.0
# Rolls-Royce      351131.0
# Lamborghini      331567.0
# Bentley          247169.0
# McLaren          239805.0
# Ferrari          238219.0
# Spyker           213323.0
# Aston Martin     197910.0
# Maserati         114208.0
# Name: MSRP, dtype: float64

# %%
cars = car_price1.select_dtypes(exclude = object)
corr = cars.corr()

# %% [markdown]
# # Generate a heatmap for the correlation matrix and explain the results

# %%
corr = cars.corr()
sb.heatmap(corr, annot = True, cmap = 'coolwarm')
# Out:
# <Axes: >

# %% [markdown]
# # Show how the Engine HP affects the Price

# %%
plt.figure(figsize=(10,6))
plt.scatter(car_price1.Engine_HP, car_price1.MSRP, color='blue', label='Engine HP vs Price')
plt.xlabel('Engine HP')
plt.ylabel('Price')
plt.title('Relationship between Engine HP and Price')
plt.legend()
plt.show()

# %% [markdown]
# # Using a bar chart, show how the transmission type affects the Price

# %% [markdown]
# Pivot table for transmission type and MSRP

# %%
transmission_pivot = car_price1.groupby(['Transmission_Type'])['MSRP'].mean().round().reset_index()
transmission_pivot
# Out:
#   Transmission_Type     MSRP
# 0  AUTOMATED_MANUAL  99508.0
# 1         AUTOMATIC  41110.0
# 2      DIRECT_DRIVE  47351.0
# 3            MANUAL  26664.0
# 4           UNKNOWN   3041.0

# %%
plt.figure(figsize=(10,6))
figure = px.bar(
    transmission_pivot,
    x = transmission_pivot.Transmission_Type,
    y = transmission_pivot.MSRP,
    title = 'Average Price of Cars by Transmission Type',
    color = transmission_pivot.index
)
figure.update_layout(yaxis_tickprefix = '$', yaxis_tickformat = '.2f')

# %% [markdown]
# # Use a pie chart to show the Vehicle Styles and their current popularity

# %%
plt.figure(figsize=(10,6))
figure = px.pie(
    car_price1,
    names = car_price1.Vehicle_Style,
    values = car_price1.Popularity,
    title = 'Pie chart for Vehicle Styles And Popularity',
    height = 700,
    width=900
    )
figure

# %% [markdown]
# # How Transmission Type is related to the Highway MPG

# %%
plt.figure(figsize=(10,6))
sb.barplot(x=car_price1.Transmission_Type, y= car_price1.highway_MPG, data=car_price1)
plt.xlabel('Transmission Type')
plt.ylabel('Highway MPG')
plt.title('Relationship between Transmission Type and Highway MPG')
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3, 4],
#  [Text(0, 0, 'MANUAL'),
#   Text(1, 0, 'AUTOMATIC'),
#   Text(2, 0, 'AUTOMATED_MANUAL'),
#   Text(3, 0, 'DIRECT_DRIVE'),
#   Text(4, 0, 'UNKNOWN')])

# %% [markdown]
# # New Machine Learning Algo For Linear Regression on Car Price 1 Dataframe

# %%
from sklearn.linear_model import LinearRegression as lr
from sklearn.model_selection import train_test_split

# %%
car_price1.columns
# Out:
# Index(['Make', 'Model', 'Year', 'Engine_Fuel_Type', 'Engine_HP',
#        'Engine_Cylinders', 'Transmission_Type', 'Driven_Wheels',
#        'Number_of_Doors', 'Market_Category', 'Vehicle_Size', 'Vehicle_Style',
#        'highway_MPG', 'city_mpg', 'Popularity', 'MSRP'],
#       dtype='object')

# %%
categorical_features = ['Make', 'Model', 'Engine_Fuel_Type', 'Transmission_Type', 'Driven_Wheels', 'Market_Category', 'Vehicle_Size', 'Vehicle_Style']
numerical_features = ['Engine_HP', 'Engine_Cylinders', 'highway_MPG', 'city_mpg', 'Popularity']
qual_features = [categorical_features + numerical_features]

# %%
car_price1.isna().sum()
car_price1.info()
car_price1.Year = car_price1.Year.astype('object')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11914 entries, 0 to 11913
# Data columns (total 16 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Make               11914 non-null  object
#  1   Model              11914 non-null  object
#  2   Year               11914 non-null  int64
#  3   Engine_Fuel_Type   11914 non-null  object
#  4   Engine_HP          11914 non-null  float64
#  5   Engine_Cylinders   11914 non-null  int64
#  6   Transmission_Type  11914 non-null  object
#  7   Driven_Wheels      11914 non-null  object
#  8   Number_of_Doors    11914 non-null  int64
#  9   Market_Category    11914 non-null  object
#  10  Vehicle_Size       11914 non-null  object
#  11  Vehicle_Style      11914 non-null  object
#  12  highway_MPG        11914 non-null  float64
#  13  city_mpg           11914 non-null  float64
#  14  Popularity         11914 non-null  int64
#  15  MSRP               11914 non-null  float64
# ...

# %% [markdown]
# # Split into 70% training and 15% testing data and 15% validation data

# %% [markdown]
# Seperating features and target

# %%
features = car_price1.drop( columns = 'MSRP')
target = car_price1.MSRP

print(features.shape)
print(target.shape)
# Out:
# (11914, 15)
# (11914,)

# %% [markdown]
# Splitting into training and testing data

# %%
features_train, features_test_init, target_train, target_test_init = train_test_split(features, target, test_size = 0.3, random_state = 11)

# %%
print(features_train.shape)
print(features_test_init.shape)
print(target_train.shape)
print(target_test_init.shape)
# Out:
# (8339, 15)
# (3575, 15)
# (8339,)
# (3575,)

# %% [markdown]
# Splitting into testing and validation data

# %%
features_test, features_valid, target_test, target_valid = train_test_split(features_test_init, target_test_init, test_size = 0.5, random_state = 11)

# %%
print(features_train.shape)
print(features_test.shape)
print(features_valid.shape)
# Out:
# (8339, 15)
# (1787, 15)
# (1788, 15)

# %%
print(target_train.shape)
print(target_test.shape)
print(target_valid.shape)
# Out:
# (8339,)
# (1787,)
# (1788,)

# %% [markdown]
# Fetch only values for th targets and shrink the data by applying the natural log

# %%
#target_test = np.log1p(target_test).values
#target_train = np.log1p(target_train).values
#target_valid = np.log1p(target_valid).values

# %% [markdown]
# Select the baseline features to be used for training and convert to numpy array

# %%
baseline_features = ['Engine_HP', 'Engine_Cylinders', 'highway_MPG', 'city_mpg', 'Popularity']
features_train_bl = features_train[baseline_features].values
features_valid_bl = features_valid[baseline_features].values
features_train_bl
# Out:
# array([[ 130.,    4.,   28.,   22.,  586.],
#        [ 200.,    4.,   28.,   20., 3105.],
#        [ 300.,    6.,   29.,   20.,  190.],
#        ...,
#        [ 221.,    6.,   26.,   17.,  210.],
#        [ 265.,    6.,   24.,   16.,  436.],
#        [ 150.,    4.,   33.,   23.,  481.]])

# %% [markdown]
# Run a linear regression algorithm on the baseline features against the target.

# %%
lrmodel = lr()
lrmodel.fit(features_train_bl, target_train)
# Out:
# LinearRegression()

# %% [markdown]
# Predict values and evaluate the model

# %%
target_validation_prediction = lrmodel.predict(features_valid_bl)
print(target_valid[0:10])
print(target_validation_prediction[0:10])
# Out:
# [10.81378033  9.97794546  8.17779668 10.91328684 10.56077437 10.8346866
#  12.43559978 10.96250973 10.07727278 10.22106818]
# [10.66273712  9.6822487   9.15790408 10.62174316 10.0689791  10.74284119
#  12.33604393 10.6269591   9.88954467  9.75896742]

# %% [markdown]
# Find the root mean squared error the mean absolute error and the r2 score

# %%
from sklearn.metrics import *
rmse = root_mean_squared_error(target_valid, target_validation_prediction)
print(f"Root Mean Squared Error (RMSE): {rmse:.2f}")
# Out:
# Root Mean Squared Error (RMSE): 0.75

# %%
accuracy = r2_score(target_valid, target_validation_prediction)
print(f'Accuracy = {accuracy:.2f}')
# Out:
# Accuracy = 0.57
