# %%
import pandas as pd
import numpy as np

toyota = pd.read_csv("Toyota.csv")
toyota.head(10)
# Out:
#    Unnamed: 0  Price   Age     KM FuelType    HP  MetColor  Automatic    CC  \
# 0           0  13500  23.0  46986   Diesel    90       1.0          0  2000
# 1           1  13750  23.0  72937   Diesel    90       1.0          0  2000
# 2           2  13950  24.0  41711   Diesel    90       NaN          0  2000
# 3           3  14950  26.0  48000   Diesel    90       0.0          0  2000
# 4           4  13750  30.0  38500   Diesel    90       0.0          0  2000
# 5           5  12950  32.0  61000   Diesel    90       0.0          0  2000
# 6           6  16900  27.0     ??   Diesel  ????       NaN          0  2000
# 7           7  18600  30.0  75889      NaN    90       1.0          0  2000
# 8           8  21500  27.0  19700   Petrol   192       0.0          0  1800
# 9           9  12950  23.0  71138   Diesel  ????       NaN          0  1900
#
#    Doors  Weight
# 0  three    1165
# 1      3    1165
# 2      3    1165
# 3      3    1165
# 4      3    1170
# 5      3    1170
# ...

# %%
toyota.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1436 entries, 0 to 1435
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  1436 non-null   int64
#  1   Price       1436 non-null   int64
#  2   Age         1336 non-null   float64
#  3   KM          1436 non-null   object
#  4   FuelType    1336 non-null   object
#  5   HP          1436 non-null   object
#  6   MetColor    1286 non-null   float64
#  7   Automatic   1436 non-null   int64
#  8   CC          1436 non-null   int64
#  9   Doors       1436 non-null   object
#  10  Weight      1436 non-null   int64
# dtypes: float64(2), int64(5), object(4)
# memory usage: 123.5+ KB

# %%
toyota.HP.unique()
# Out:
# array(['90', '????', '192', '110', '97', '71', '116', '98', '69', '86',
#        '72', '107', '73'], dtype=object)

# %%
toyota.HP.value_counts()
# Out:
# HP
# 110     833
# 86      249
# 97      164
# 72       72
# 90       35
# 69       33
# 107      21
# 192      10
# 116       9
# ????      6
# 98        2
# 71        1
# 73        1
# Name: count, dtype: int64

# %%
cars = pd.read_csv("Toyota.csv", index_col= 0)
cars

cancer = pd.read_csv("cancer.csv")
cancer
# Out:
#      id          diagnosis   radius_mean   texture_mean   perimeter_mean   \
# 0        842302  M                  17.99          10.38           122.80
# 1        842517  M                  20.57          17.77           132.90
# 2      84300903  M                  19.69          21.25           130.00
# 3      84348301  M                  11.42          20.38            77.58
# 4      84358402  M                  20.29          14.34           135.10
# ..          ...         ...           ...            ...              ...
# 564      926424  M                  21.56          22.39           142.00
# 565      926682  M                  20.13          28.25           131.20
# 566      926954  M                  16.60          28.08           108.30
# 567      927241  M                  20.60          29.33           140.10
# 568       92751  B                   7.76          24.54            47.92
#
#      area_mean   smoothness_mean   compactness_mean   concavity_mean   \
# ...

# %%
cars
# Out:
#       Price   Age     KM FuelType   HP  MetColor  Automatic    CC  Doors  \
# 0     13500  23.0  46986   Diesel   90       1.0          0  2000  three
# 1     13750  23.0  72937   Diesel   90       1.0          0  2000      3
# 2     13950  24.0  41711   Diesel   90       NaN          0  2000      3
# 3     14950  26.0  48000   Diesel   90       0.0          0  2000      3
# 4     13750  30.0  38500   Diesel   90       0.0          0  2000      3
# ...     ...   ...    ...      ...  ...       ...        ...   ...    ...
# 1431   7500   NaN  20544   Petrol   86       1.0          0  1300      3
# 1432  10845  72.0     ??   Petrol   86       0.0          0  1300      3
# 1433   8500   NaN  17016   Petrol   86       0.0          0  1300      3
# 1434   7250  70.0     ??      NaN   86       1.0          0  1300      3
# 1435   6950  76.0      1   Petrol  110       0.0          0  1600      5
#
#       Weight
# 0       1165
# 1       1165
# 2       1165
# 3       1165
# 4       1170
# ...

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 123.4+ KB

# %%
cars.KM.unique()
cars.KM.value_counts()

# %%
cars.FuelType.unique()
cars.FuelType.value_counts()
# Out:
# FuelType
# Petrol    1177
# Diesel     144
# CNG         15
# Name: count, dtype: int64

# %%
cars.HP.unique()
cars.HP.value_counts(ascending = True)
# Out:
# HP
# 71        1
# 73        1
# 98        2
# ????      6
# 116       9
# 192      10
# 107      21
# 69       33
# 90       35
# 72       72
# 97      164
# 86      249
# 110     833
# Name: count, dtype: int64

# %%
cars.Doors.unique()
cars.Doors.value_counts()
# Out:
# Doors
# 5        673
# 3        621
# 4        137
# 2          2
# three      1
# four       1
# five       1
# Name: count, dtype: int64

# %%
cars.MetColor.unique()
# Out:
# array([ 1., nan,  0.])

# %%
cars.head(60)

# %%
cars.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1431    False
# 1432    False
# 1433    False
# 1434    False
# 1435    False
# Length: 1436, dtype: bool

# %%
cars_dropped = cars.dropna()
cars_dropped.head(60)
# Out:
#     Price   Age     KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0  46986   Diesel    90       1.0          0  2000  three
# 1   13750  23.0  72937   Diesel    90       1.0          0  2000      3
# 3   14950  26.0  48000   Diesel    90       0.0          0  2000      3
# 4   13750  30.0  38500   Diesel    90       0.0          0  2000      3
# 5   12950  32.0  61000   Diesel    90       0.0          0  2000      3
# 8   21500  27.0  19700   Petrol   192       0.0          0  1800      3
# 10  20950  25.0  31461   Petrol   192       0.0          0  1800      3
# 11  19950  22.0  43610   Petrol   192       0.0          0  1800      3
# 12  19600  25.0  32189   Petrol   192       0.0          0  1800      3
# 13  21500  31.0  23000   Petrol   192       1.0          0  1800      3
# 14  22500  32.0  34131   Petrol   192       1.0          0  1800      3
# 15  22000  28.0  18739   Petrol  ????       0.0          0  1800      3
# ...

# %%
cars.isnull().sum()
# Out:
# Price          0
# Age          100
# KM             0
# FuelType     100
# HP             0
# MetColor     150
# Automatic      0
# CC             0
# Doors          0
# Weight         0
# dtype: int64

# %%
cars_dropped1 = cars.copy()
cars_dropped1.drop(columns = ['Age', 'FuelType', 'MetColor'], inplace = True)
cars_dropped1.head(60)
# Out:
#     Price      KM    HP  Automatic    CC  Doors  Weight
# 0   13500   46986    90          0  2000  three    1165
# 1   13750   72937    90          0  2000      3    1165
# 2   13950   41711    90          0  2000      3    1165
# 3   14950   48000    90          0  2000      3    1165
# 4   13750   38500    90          0  2000      3    1170
# 5   12950   61000    90          0  2000      3    1170
# 6   16900      ??  ????          0  2000      3    1245
# 7   18600   75889    90          0  2000      3    1245
# 8   21500   19700   192          0  1800      3    1185
# 9   12950   71138  ????          0  1900      3    1105
# 10  20950   31461   192          0  1800      3    1185
# 11  19950   43610   192          0  1800      3    1185
# 12  19600   32189   192          0  1800      3    1185
# 13  21500   23000   192          0  1800      3    1185
# 14  22500   34131   192          0  1800      3    1185
# 15  22000   18739  ????          0  1800      3    1185
# ...

# %%
cars_dropped.replace('?', np.nan)
cars.head(60)
# Out:
#     Price   Age      KM FuelType    HP  MetColor  Automatic    CC  Doors  \
# 0   13500  23.0   46986   Diesel    90       1.0          0  2000  three
# 1   13750  23.0   72937   Diesel    90       1.0          0  2000      3
# 2   13950  24.0   41711   Diesel    90       NaN          0  2000      3
# 3   14950  26.0   48000   Diesel    90       0.0          0  2000      3
# 4   13750  30.0   38500   Diesel    90       0.0          0  2000      3
# 5   12950  32.0   61000   Diesel    90       0.0          0  2000      3
# 6   16900  27.0      ??   Diesel  ????       NaN          0  2000      3
# 7   18600  30.0   75889      NaN    90       1.0          0  2000      3
# 8   21500  27.0   19700   Petrol   192       0.0          0  1800      3
# 9   12950  23.0   71138   Diesel  ????       NaN          0  1900      3
# 10  20950  25.0   31461   Petrol   192       0.0          0  1800      3
# 11  19950  22.0   43610   Petrol   192       0.0          0  1800      3
# ...

# %%
cars2 = cars.copy()

# %%
cars2.replace('?????', np.nan, inplace = True)
cars2.head(60)

# %%
toyotoyo = pd.read_csv('Toyota.csv', index_col = 0, na_values= ['????', '???', '??', '?'])

# %%
toyotoyo.describe()
# Out:
#               Price          Age             KM           HP     MetColor  \
# count   1436.000000  1336.000000    1421.000000  1430.000000  1286.000000
# mean   10730.824513    55.672156   68647.239972   101.478322     0.674961
# std     3626.964585    18.589804   37333.023589    14.768255     0.468572
# min     4350.000000     1.000000       1.000000    69.000000     0.000000
# 25%     8450.000000    43.000000   43210.000000    90.000000     0.000000
# 50%     9900.000000    60.000000   63634.000000   110.000000     1.000000
# 75%    11950.000000    70.000000   87000.000000   110.000000     1.000000
# max    32500.000000    80.000000  243000.000000   192.000000     1.000000
#
#          Automatic           CC      Weight
# count  1436.000000  1436.000000  1436.00000
# mean      0.055710  1566.827994  1072.45961
# std       0.229441   187.182436    52.64112
# min       0.000000  1300.000000  1000.00000
# 25%       0.000000  1400.000000  1040.00000
# ...

# %%
round(toyotoyo.Age.mean())
# Out:
# 55.67

# %%
cars.Age.replace(np.nan, round(cars.Age.mean()), inplace = True)
cars.head(60)

# %%
cars.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   object
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   object
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(2), int64(4), object(4)
# memory usage: 123.4+ KB

# %%
toyotoyo.MetColor.fillna(toyotoyo.MetColor.mean(), inplace =True)
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_5176\1180571401.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   toyotoyo.MetColor.fillna(toyotoyo.MetColor.mean(), inplace =True)

# %%
toyotoyo.Doors.replace(['three', 'four', 'five'], [3, 4, 5], inplace = True)
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_5176\2245336140.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   toyotoyo.Doors.replace(['three', 'four', 'five'], [3, 4, 5], inplace = True)

# %%
toyotoyo.Doors.astype('int64')
toyotoyo.head()
# Out:
#    Price   Age       KM FuelType    HP  MetColor  Automatic    CC Doors  \
# 0  13500  23.0  46986.0   Diesel  90.0       1.0          0  2000     3
# 1  13750  23.0  72937.0   Diesel  90.0       1.0          0  2000     3
# 2  13950  24.0  41711.0   Diesel  90.0       NaN          0  2000     3
# 3  14950  26.0  48000.0   Diesel  90.0       0.0          0  2000     3
# 4  13750  30.0  38500.0   Diesel  90.0       0.0          0  2000     3
#
#    Weight
# 0    1165
# 1    1165
# 2    1165
# 3    1165
# 4    1170

# %%
toyotoyo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1336 non-null   float64
#  2   KM         1421 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 123.4+ KB

# %%
toyotoyo.Age.fillna(toyotoyo.Age.mean(), inplace = True)
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_5176\3964254110.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   toyotoyo.Age.fillna(toyotoyo.Age.mean(), inplace = True)

# %%
toyotoyo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1430 non-null   float64
#  5   MetColor   1286 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 123.4+ KB

# %%
toyotoyo.KM.replace(np.nan, toyotoyo.KM.median(), inplace = True)
toyotoyo.HP.replace(np.nan, toyotoyo.HP.mean(), inplace = True)
# Out:
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_5176\292645101.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   toyotoyo.KM.replace(np.nan, toyotoyo.KM.median(), inplace = True)
# C:\Users\Dwayne\AppData\Local\Temp\ipykernel_5176\292645101.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# ...

# %%
toyotoyo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 1436 entries, 0 to 1435
# Data columns (total 10 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Price      1436 non-null   int64
#  1   Age        1436 non-null   float64
#  2   KM         1436 non-null   float64
#  3   FuelType   1336 non-null   object
#  4   HP         1436 non-null   float64
#  5   MetColor   1436 non-null   float64
#  6   Automatic  1436 non-null   int64
#  7   CC         1436 non-null   int64
#  8   Doors      1436 non-null   object
#  9   Weight     1436 non-null   int64
# dtypes: float64(4), int64(4), object(2)
# memory usage: 123.4+ KB
